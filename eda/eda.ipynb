# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Create Shortened DataFrame

# %%
# Load Data...
data = [json.loads(line) for line in open("./data/data.jsonl", 'r', encoding='utf-8')]
df = pd.DataFrame(data)


### Create Summary DataFrame for Reference
# Create list for columns used, 1 for used feature, 0 for not used feature
use = [1      # created_at
       , 0    # id
       , 1    # id_str
       , 1    # full_text
       , 0    # truncated
       , 1    # display_text_range
       , 1    # entities
       , 1    # source
       , 0    # in_reply_to_status_id
       , 0    # in_reply_to_status_id_str
       , 0    # in_reply_to_user_id
       , 0    # in_reply_to_user_id_str
       , 0    # in_reply_to_screen_name
       , 1    # user
       , 0    # geo 
       , 0    # coordinates
       , 0    # place (maybe)
       , 0    # contributors
       , 1    # is_quote_status
       , 0    # quoted_status_id 
       , 0    # quoted_status_id_str 
       , 0    # quoted_status_permalink
       , 0    # quoted_status (maybe)
       , 1    # retweet_count 
       , 1    # favorite_count
       , 0    # favorited
       , 0    # retweeted
       , 1    # possibly_sensitive 
       , 1    # lang
       , 1    # retweeted_status
       , 0    # extended_entities (maybe)
       , 0    # withheld_in_countries
       ]

# Create a dictionary with summary information
dict_ = {'feature': list(df.columns)
         , 'nulls': df.isna().sum().values
         , 'non_nulls': df.notnull().sum().values
         , 'use': use
        }
summary_df = pd.DataFrame(dict_)


### Shorten Columns
# create a list of dropped column names
drop_col = list(summary_df.feature[summary_df.use !=1])

# create a df_short dataframe with only the columns we need
df = df.drop(columns = drop_col)

# create a list of kept column names
use_col = list(summary_df.feature[summary_df.use==1])

# verify used columns are present
print(f'Used Columns Are Present: {use_col == list(df.columns)}')

# create datetime column
df['datetime'] = pd.to_datetime(df.created_at)

# drop created_at
df.drop('created_at'
        , axis=1
        , inplace=True
       )
# Out:
# Used Columns Are Present: True

# %%
df.head()
# Out:
#                 id_str                                          full_text  \
# 0  1311093385688735744  Biden a professional debater??  Hardly!! More ...
# 1  1311093394400333824  RT @DarDar458: #PresidentialDebate #Debates202...
# 2  1311093401652277252  How can Biden stand a chance against Trump in ...
# 3  1311093410737070086  RT @abbydphillip: Very reminiscent of pre-2018...
# 4  1311093419100561408  RT @RudyGiuliani: Why was Corrupt Biden’s son ...
#
#   display_text_range                                           entities  \
# 0            [0, 71]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1            [0, 73]  {'hashtags': [{'text': 'PresidentialDebate', '...
# 2           [0, 280]  {'hashtags': [{'text': 'VarneyCo', 'indices': ...
# 3           [0, 108]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 110]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                               source  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="https://studio.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 117904481, 'id_str': '117904481', 'name...             True
# 1  {'id': 30140760, 'id_str': '30140760', 'name':...             True
# 2  {'id': 281610530, 'id_str': '281610530', 'name...            False
# 3  {'id': 88223320, 'id_str': '88223320', 'name':...             True
# 4  {'id': 44295160, 'id_str': '44295160', 'name':...            False
#
#    retweet_count  favorite_count possibly_sensitive lang  \
# 0              0               0              False   en
# 1              1               0                NaN  und
# 2             25             100              False   en
# 3            351               0                NaN   en
# 4          15672               0                NaN   en
#
#                                     retweeted_status                  datetime
# 0                                                NaN 2020-09-29 23:59:56+00:00
# 1  {'created_at': 'Tue Sep 29 23:55:42 +0000 2020... 2020-09-29 23:59:58+00:00
# 2                                                NaN 2020-09-30 00:00:00+00:00
# 3  {'created_at': 'Tue Sep 29 23:00:28 +0000 2020... 2020-09-30 00:00:02+00:00
# 4  {'created_at': 'Tue Sep 29 19:07:59 +0000 2020... 2020-09-30 00:00:04+00:00

# %%
df.columns
# Out:
# Index(['id_str', 'full_text', 'display_text_range', 'entities', 'source',
#        'user', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'possibly_sensitive', 'lang', 'retweeted_status', 'datetime'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140337 entries, 0 to 140336
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id_str              140337 non-null  object
#  1   full_text           140337 non-null  object
#  2   display_text_range  140337 non-null  object
#  3   entities            140337 non-null  object
#  4   source              140337 non-null  object
#  5   user                140337 non-null  object
#  6   is_quote_status     140337 non-null  bool
#  7   retweet_count       140337 non-null  int64
#  8   favorite_count      140337 non-null  int64
#  9   possibly_sensitive  32333 non-null   object
#  10  lang                140337 non-null  object
#  11  retweeted_status    106900 non-null  object
#  12  datetime            140337 non-null  datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](1), int64(2), object(9)
# memory usage: 13.0+ MB

# %% [markdown]
# ## Min and Max Dates

# %%
print(f'Earliest date: {df.datetime.min()}')
print(f'Latest date: {df.datetime.max()}')
# Out:
# Earliest date: 2020-09-29 23:59:56+00:00
# Latest date: 2020-10-02 23:59:54+00:00

# %% [markdown]
# ## Create columns with numbers

# %% [markdown]
# ## id_str column review

# %%
# there are 140,337 tweet id's (I think)
df.id_str.nunique()
# Out:
# 140337

# %% [markdown]
# ### display_text_range column to int()

# %%
type(df.display_text_range.iloc[0])
# Out:
# list

# %%
df.display_text_range.iloc[0][-1]
# Out:
# 71

# %%
def text_length(lst):
    """
    Parses the end of list [0, 15] returns 15
    
    Input: lst, column entry as from display_text_range
    Output: int, length of tweet
    """
    return lst[-1]

# %%
df['text_length'] = df.display_text_range.apply(text_length)

# %%
# Drop display_text_range
df.drop('display_text_range'
        , axis = 1
        , inplace = True
       )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140337 entries, 0 to 140336
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id_str              140337 non-null  object
#  1   full_text           140337 non-null  object
#  2   entities            140337 non-null  object
#  3   source              140337 non-null  object
#  4   user                140337 non-null  object
#  5   is_quote_status     140337 non-null  bool
#  6   retweet_count       140337 non-null  int64
#  7   favorite_count      140337 non-null  int64
#  8   possibly_sensitive  32333 non-null   object
#  9   lang                140337 non-null  object
#  10  retweeted_status    106900 non-null  object
#  11  datetime            140337 non-null  datetime64[ns, UTC]
#  12  text_length         140337 non-null  int64
# dtypes: bool(1), datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 13.0+ MB

# %% [markdown]
# ### entities column (come back to this wtih Julia and Mathias)

# %%
df.entities.iloc[0]
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': [{'url': 'https://t.co/cQuxzexXYt',
#    'expanded_url': 'https://twitter.com/IngrahamAngle/status/1311081374510710784',
#    'display_url': 'twitter.com/IngrahamAngle/…',
#    'indices': [72, 95]}]}

# %%
df.entities.iloc[1]
# Out:
# {'hashtags': [{'text': 'PresidentialDebate', 'indices': [15, 34]},
#   {'text': 'Debates2020', 'indices': [35, 47]},
#   {'text': 'TrumpIsANationalDisgrace', 'indices': [48, 73]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'DarDar458',
#    'name': 'DarDar45 🌊 🆘',
#    'id': 1084234892840484864,
#    'id_str': '1084234892840484864',
#    'indices': [3, 13]}],
#  'urls': []}

# %%
df.entities.iloc[100]
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'HizbkKhan',
#    'name': 'Hizbullah Khan',
#    'id': 1015029427284127745,
#    'id_str': '1015029427284127745',
#    'indices': [3, 13]}],
#  'urls': [],
#  'media': [{'id': 1310731423184191493,
#    'id_str': '1310731423184191493',
#    'indices': [93, 116],
#    'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1310731423184191493/pu/img/kXb4Oq2Wb0p8on5F.jpg',
#    'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1310731423184191493/pu/img/kXb4Oq2Wb0p8on5F.jpg',
#    'url': 'https://t.co/XnGBT6jpLl',
#    'display_url': 'pic.twitter.com/XnGBT6jpLl',
#    'expanded_url': 'https://twitter.com/HizbkKhan/status/1310731479748669440/video/1',
#    'type': 'photo',
#    'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'medium': {'w': 628, 'h': 360, 'resize': 'fit'},
#     'large': {'w': 628, 'h': 360, 'resize': 'fit'},
#     'small': {'w': 628, 'h': 360, 'resize': 'fit'}},
#    'source_status_id': 1310731479748669440,
#    'source_status_id_str': '1310731479748669440',
#    'source_user_id': 1015029427284127745,
#    'source_user_id_str': '1015029427284127745'}]}

# %% [markdown]
# ### source column

# %%
df.source.iloc[0]
# Out:
# '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>'

# %%
# write a function to prase between <a></a>

from bs4 import BeautifulSoup

def btw_a(txt):
    """
    Returns text between the <a></a>
    Input: txt
    Output: txt
    """
    soup = BeautifulSoup(txt)
    for x in soup.find_all('a'):
        return x.get_text()

# %%
# test the function btw_a
txt = '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>'
btw_a(txt)
# Out:
# 'Twitter Web App'

# %%
# apply it to source column
df.source = df.source.apply(btw_a)

# %%
# check work
df.source.head()
# Out:
# 0         Twitter Web App
# 1      Twitter for iPhone
# 2    Twitter Media Studio
# 3      Twitter for iPhone
# 4      Twitter for iPhone
# Name: source, dtype: object

# %%
# find the unique values
df.source.value_counts()
# Out:
# Twitter for iPhone         62080
# Twitter for Android        38641
# Twitter Web App            29655
# Twitter for iPad            8046
# TweetDeck                    459
#                            ...
# tsartbot                       1
# zeroedtweets                   1
# Sam R                          1
# Españolimetro                  1
# Guanduania Humanitarian        1
# Name: source, Length: 310, dtype: int64

# %%
len(df.source.value_counts())
# Out:
# 310

# %%
source_lst = df.source.value_counts().index
source_lst
# Out:
# Index(['Twitter for iPhone', 'Twitter for Android', 'Twitter Web App',
#        'Twitter for iPad', 'TweetDeck', 'Tweetbot for iΟS', 'WordPress.com',
#        'dlvr.it', 'IFTTT', 'Twitter for Mac',
#        ...
#        'Bad News for Trump', 'Reddit Tweeter ', 'SocialDog for Twitter',
#        'Grassroots DNC', 'App for DutchCryptoTalk.com', 'tsartbot',
#        'zeroedtweets', 'Sam R', 'Españolimetro', 'Guanduania Humanitarian'],
#       dtype='object', length=310)

# %% [markdown]
# ### user column

# %%
df.user.iloc[0]
# Out:
# {'id': 117904481,
#  'id_str': '117904481',
#  'name': 'SharonS',
#  'screen_name': 'sfshores53',
#  'location': 'America ',
#  'description': 'Conservative/#MAGA/ #WWG1WGA /MbrNRA/#Trump2020/Pro-Life/Pro-2nd Amend/parler@SharonA53/ NO DMs-/Patriots-will follow all/will unfollow those who do not follow',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 4065,
#  'friends_count': 4998,
#  'listed_count': 16,
#  'created_at': 'Sat Feb 27 00:36:23 +0000 2010',
#  'favourites_count': 3659,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 6156,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '0099B9',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1285573452330610690/ZqF7b43V_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285573452330610690/ZqF7b43V_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/117904481/1595345887',
#  'profile_image_extensions_alt_text': None,
#  'profile_banner_extensions_alt_text': None,
#  'profile_link_color': '003DB8',
#  'profile_sidebar_border_color': '5ED4DC',
#  'profile_sidebar_fill_color': '95E8EC',
#  'profile_text_color': '3C3940',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
type(df.user.iloc[0])
# Out:
# dict

# %%
# create function to pull out user profile value from user dictionary
def user_id(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: str, user_id
    """    
    return dict_['id_str']

# %%
# create user id column
df['user_id'] = df.user.apply(user_id)

# %%
# there are 121,040 unique user id's
df.user_id.nunique()
# Out:
# 121040

# %%
# user follower_count sample
df.user.iloc[0]['followers_count']
# Out:
# 4065

# %%
# create function to pull out user profile value from user dictionary
def followers_count(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: int, followers_count
    """    
    return dict_['followers_count']

# %%
# create followers count column
df['followers_count'] = df.user.apply(followers_count)

# %%
# check data type
type(df.followers_count.iloc[0])
# Out:
# numpy.int64

# %%
# user friends__count sample
df.user.iloc[0]['friends_count']
# Out:
# 4998

# %%
# create function to pull out user profile value from user dictionary
def friends_count(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: int, friends_count
    """    
    return dict_['friends_count']

# %%
# create followers count column
df['friends_count'] = df.user.apply(friends_count)

# %%
# check data type
type(df.friends_count.iloc[0])
# Out:
# numpy.int64

# %%
# user location sample
df.user.iloc[0]['location']
# Out:
# 'America '

# %%
# create function to pull out user profile value from user dictionary
def location(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: str, location
    """    
    return dict_['location']

# %%
# create user locations column
df['user_location'] = df.user.apply(location)

# %%
# check data type
type(df.user_location.iloc[0])
# Out:
# str

# %%
# user created sample
df.user.iloc[0]['created_at']
# Out:
# 'Sat Feb 27 00:36:23 +0000 2010'

# %%
# create function to pull out user profile value from user dictionary
def acc_created(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: str, account created
    """    
    return dict_['created_at']

# %%
# create user locations column
df['acct_created'] = df.user.apply(acc_created)

# %%
# check data type
type(df.acct_created.iloc[0])
# Out:
# str

# %%
# user statuses_count sample
df.user.iloc[0]['statuses_count']
# Out:
# 6156

# %%
# create function to pull out user profile value from user dictionary
def statuses_count(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: int, statuses_count
    """    
    return dict_['statuses_count']

# %%
# create user statuses_count column
df['statuses_count'] = df.user.apply(statuses_count)

# %%
# check data type
type(df.statuses_count.iloc[0])
# Out:
# numpy.int64

# %%
# user following sample
df.user.iloc[0]['following']
# Out:
# False

# %%
# create function to pull out user profile value from user dictionary
def following(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: bool, following
    """    
    return dict_['following']

# %%
# create user following column
df['following'] = df.user.apply(following)

# %%
# check data type
type(df.following.iloc[0])
# Out:
# numpy.bool_

# %%
# user following_request_sent sample
df.user.iloc[0]['follow_request_sent']
# Out:
# False

# %%
# create function to pull out user profile value from user dictionary
def following_request(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: bool, following
    """    
    return dict_['follow_request_sent']

# %%
# create user following column
df['following_request'] = df.user.apply(following_request)

# %%
# check data type
type(df.following_request.iloc[0])
# Out:
# numpy.bool_

# %%
# user following_request_sent sample
df.user.iloc[0]['notifications']
# Out:
# False

# %%
# create function to pull out user profile value from user dictionary
def notifications(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: bool, notifications
    """    
    return dict_['notifications']

# %%
# create user following column
df['notifications'] = df.user.apply(notifications)

# %%
# check data type
type(df.notifications.iloc[0])
# Out:
# numpy.bool_

# %%
# user description sample
df.user.iloc[0]['description']
# Out:
# 'Conservative/#MAGA/ #WWG1WGA /MbrNRA/#Trump2020/Pro-Life/Pro-2nd Amend/parler@SharonA53/ NO DMs-/Patriots-will follow all/will unfollow those who do not follow'

# %%
# create function to pull out user profile value from user dictionary
def user_descriptions(dict_):
    """
    Pulls out user id from user dictionary
    Input: dict, user dictionary
    Output: str, user_descriptions
    """    
    return dict_['description']

# %%
# create user following column
df['user_descriptions'] = df.user.apply(user_descriptions)

# %%
# check data type
type(df.user_descriptions.iloc[0])
# Out:
# str

# %% [markdown]
# ## Creating A Influencing Score

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140337 entries, 0 to 140336
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id_str              140337 non-null  object
#  1   full_text           140337 non-null  object
#  2   entities            140337 non-null  object
#  3   source              140319 non-null  object
#  4   user                140337 non-null  object
#  5   is_quote_status     140337 non-null  bool
#  6   retweet_count       140337 non-null  int64
#  7   favorite_count      140337 non-null  int64
#  8   possibly_sensitive  32333 non-null   object
#  9   lang                140337 non-null  object
#  10  retweeted_status    106900 non-null  object
#  11  datetime            140337 non-null  datetime64[ns, UTC]
#  12  text_length         140337 non-null  int64
#  13  user_id             140337 non-null  object
#  14  followers_count     140337 non-null  int64
#  15  friends_count       140337 non-null  int64
#  16  user_location       140337 non-null  object
#  17  acct_created        140337 non-null  object
#  18  statuses_count      140337 non-null  int64
#  19  following           140337 non-null  bool
#  20  following_request   140337 non-null  bool
#  21  notifications       140337 non-null  bool
#  22  user_descriptions   140337 non-null  object
# dtypes: bool(4), datetime64[ns, UTC](1), int64(6), object(12)
# memory usage: 20.9+ MB

# %% [markdown]
# ## The int() columns seems interesting, investigate further

# %%
# retweet_count stats:
df.retweet_count.mean(), df.retweet_count.median(), df.retweet_count.std()
# Out:
# (21028.81549413198, 859.0, 66438.94603761076)

# %%
# favorite_count stats:
df.favorite_count.mean(), df.favorite_count.median(), df.favorite_count.std()
# Out:
# (4.9153395041934775, 0.0, 661.1712932699155)

# %%
# text_length stats:
df.text_length.mean(), df.text_length.median(), df.text_length.std()
# Out:
# (118.03955478597946, 139.0, 52.76082452811671)

# %%
# followers_count stats:
df.followers_count.mean(), df.followers_count.median(), df.followers_count.std()
# Out:
# (6257.545629449111, 423.0, 349213.32380061835)

# %%
# friends_count stats:
df.friends_count.mean(), df.friends_count.median(), df.friends_count.std()
# Out:
# (2503.2387253539696, 690.0, 7632.612775724196)

# %%
# statuses_count stats:
df.statuses_count.mean(), df.statuses_count.median(), df.statuses_count.std()
# Out:
# (50793.964207586025, 17076.0, 102684.62866876785)

# %% [markdown]
# ## full_text analysis

# %%
# is this a negative or positive comment?
df.full_text.iloc[0]
# Out:
# 'Biden a professional debater??  Hardly!! More like a professional liar! https://t.co/cQuxzexXYt'

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/david/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()

# %%
df['sentiment_scores'] = df.full_text.apply(lambda x: sia.polarity_scores(x))

# %%
df.sentiment_scores.iloc[0]
# Out:
# {'neg': 0.335, 'neu': 0.489, 'pos': 0.176, 'compound': -0.5081}

# %%
df['compound_score'] = df.sentiment_scores.apply(lambda x: x['compound'])

# %%
df['sentiment'] = df.compound_score.apply(lambda x: 1 if x > 0 else (0 if x==0 else -1))

# %%
df.sentiment.value_counts()
# Out:
#  1    50527
# -1    45748
#  0    44062
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Biden Trump Mentions in full_text

# %%
# find Biden mentions in full_text
df['Biden_mentions'] = df.full_text.apply(lambda x: x.lower()).str.find('biden')
df['Biden_mentions'] = df.Biden_mentions.apply(lambda x: -1 if x==-1 else 1)
df.Biden_mentions.value_counts()
# Out:
# -1    102438
#  1     37899
# Name: Biden_mentions, dtype: int64

# %%
# find Trump mentions in full_text
df['Trump_mentions'] = df.full_text.apply(lambda x: x.lower()).str.find('trump')
df['Trump_mentions'] = df.Trump_mentions.apply(lambda x: -1 if x==-1 else 1)
df.Trump_mentions.value_counts()
# Out:
#  1    82711
# -1    57626
# Name: Trump_mentions, dtype: int64

# %% [markdown]
# ## Popular hastags in user_descriptions

# %%
# user_descriptions hastags
df.user_descriptions.iloc[3]
# Out:
# 'Politics reporter covering elections & voting @businessinsider. Bad speller. Extremely New England. RTs/likes=👀not👍🏼 say hi/send tips to gpanetta@insider.com'

# %%
import re
sent = df.user_descriptions.iloc[1]
re.findall(r"#(\w+)", sent)
# Out:
# ['Resisters', 'BlueNoMatterWho', 'BlackLivesMatter', 'NoDMs', 'RightMatters']

# %%
sent = df.user_descriptions.iloc[4]
re.findall(r"#(\w+)", sent)
# Out:
# []

# %%
# hastags mentioned in text
sent = df.full_text.iloc[2]
sent
# Out:
# 'How can Biden stand a chance against Trump in tonight\'s Presidential Debate? @wjmcgurn says he needs to stay calm, like how he was against Paul Ryan in 2012: "The best thing he can do is leave Angry Joe in the basement. I don\'t think he can out-Trump Trump." #VarneyCo #2020Debate https://t.co/DKU4ausBzT'

# %%
re.findall(r"#(\w+)", sent)
# Out:
# ['VarneyCo', '2020Debate']

# %%
user_descriptions_hastags = df.user_descriptions.apply(lambda x: re.findall(r"#(\w+)", x))

# %%
user_descriptions_hastags_dict = {}
for x in user_descriptions_hastags:
    for y in x:
        if y.lower() in user_descriptions_hastags_dict:
            user_descriptions_hastags_dict[y.lower()] += 1
        else:
            user_descriptions_hastags_dict[y.lower()] = 1

# %%
user_descriptions_hastags_dict
# Out:
# {'maga': 8446,
#  'wwg1wga': 2163,
#  'trump2020': 3631,
#  'resisters': 38,
#  'bluenomatterwho': 16,
#  'blacklivesmatter': 1823,
#  'nodms': 16,
#  'rightmatters': 56,
#  'obamaalumni': 1,
#  'deplorable': 190,
#  'intactivist': 1,
#  'tump': 1,
#  'usa': 220,
#  'always': 4,
#  'kag': 3752,
#  'cherokeeproud': 1,
#  'mmiw': 16,
#  'indegiousresistance': 1,
#  'uglydogs': 5,
#  'resistance': 868,
#  'americafirst': 603,
#  'ingodwetrust': 49,
#  'jeep': 6,
#  'renegade': 3,
#  'backtheblue': 732,
#  'handsoffmyguns': 5,
#  'gunchick': 4,
#  'shelties': 5,
#  'nevergiveup': 5,
#  'dreambig': 3,
#  'selfemployed': 1,
#  'entrepreneur': 20,
#  'electoralcollege': 2,
#  'savethechildren': 390,
#  'thegreatawakening': 219,
#  'kag2020': 717,
#  'declas': 4,
#  'nra': 825,
#  'prolife': 809,
#  'socialismkills': 10,
#  'democratsarethepartyofsatan': 4,
#  'resist': 3425,
#  'american': 38,
#  'patriot': 843,
#  'wwgiwga': 5,
#  '2a': 1682,
#  'theresistance': 1072,
#  'socialjustice': 17,
#  'socialdemocrat': 3,
#  'hr': 2,
#  'fbr': 1026,
#  'bluewave': 353,
#  'blm': 1916,
#  'israel': 117,
#  'bluetsunami': 37,
#  'reunitemigrantfamilies': 1,
#  'resisttomakeamericablueagain': 1,
#  'nyy': 8,
#  'biden': 167,
#  'fucktrump': 180,
#  'mysignaturejokes': 2,
#  'fresh': 13,
#  'demcast': 85,
#  'wtpbiden': 5,
#  'nwx4l': 1,
#  'riptashane': 1,
#  'freequestaffa': 1,
#  'freebhrisgunz': 1,
#  'imfromjacksonave': 1,
#  'gvg': 1,
#  'unity2020': 3,
#  'americanpatriot': 9,
#  'patriotsunite': 16,
#  'patriotsawakened': 4,
#  'patriotsfight': 13,
#  'conservative': 657,
#  'pro2nd': 5,
#  'secondamendment': 5,
#  'americanspirit': 2,
#  'anzoategui': 1,
#  'usmc': 75,
#  'votetrumpout': 16,
#  'joebiden2020': 58,
#  'queenfan': 2,
#  'freddiemercury': 2,
#  'buddhist': 4,
#  'bidenharris': 383,
#  'gop': 46,
#  'pelosihypocrite': 1,
#  'ufc': 14,
#  'mma': 18,
#  'wwe': 9,
#  'fightback': 315,
#  'taketheoath': 136,
#  'q': 279,
#  'digitalsoldier': 120,
#  'biden2020': 534,
#  'diehardpinkfloydfan': 3,
#  'davidgilmourforever': 3,
#  'clemson': 8,
#  'cru': 6,
#  'hrc': 6,
#  'votevets': 10,
#  'love': 81,
#  'eaglescout': 5,
#  'suntzu': 1,
#  'freegeneralflynn': 7,
#  'sparklefan': 6,
#  'buildthewall': 616,
#  'vets': 142,
#  '1a': 644,
#  'bluelivesmatter': 278,
#  'nufc': 5,
#  'libertarian': 27,
#  'flyeaglesfly': 28,
#  'registertovote': 5,
#  'voteblue': 757,
#  'voteforourlives': 7,
#  'resister': 291,
#  'qal': 1,
#  'glambert': 2,
#  'loveislove': 47,
#  'stillwithher': 177,
#  'shewon': 15,
#  'bekindtooneanother': 1,
#  'thankyoupresidenttrump': 4,
#  'keepamericagreat': 88,
#  'culinaryarts': 3,
#  'presidentbiden': 16,
#  'defeattheorange': 3,
#  'saveourwildhorses': 3,
#  'climatechange': 84,
#  'oneracehumanrace': 3,
#  'lac': 1,
#  'christiansagainsttrump': 6,
#  'bidenharris2020': 1794,
#  'fakenews': 48,
#  'fakedoctor': 4,
#  'snowflake': 8,
#  'chicken': 4,
#  'loathsome': 4,
#  'savetheplanet': 14,
#  'equalrightsforall': 3,
#  'savetheusps': 23,
#  'wearamask': 175,
#  'lqbtq': 2,
#  'nomasks': 23,
#  'defunduniversities': 1,
#  'potus': 119,
#  'sports': 17,
#  'bsu': 4,
#  'ncaa': 2,
#  'nfl': 12,
#  'tech': 18,
#  'geek': 11,
#  'news': 28,
#  'politics': 54,
#  'obama': 19,
#  'beto': 7,
#  'bleedblue': 3,
#  'nevertrump': 253,
#  'trump': 812,
#  'covfefe': 77,
#  'μολωνλαβε': 42,
#  'peace': 46,
#  'kindness': 8,
#  'unity': 8,
#  'lawofone': 1,
#  'edgarcayce': 1,
#  'votevotevote': 1,
#  'impeachbarrnow': 4,
#  'closethecamps': 25,
#  'releasethetaxes': 2,
#  'flipthesenate': 57,
#  'lgbt': 52,
#  'yanggang': 59,
#  'christfollower': 3,
#  'proud': 27,
#  '1stgenamerican': 1,
#  'faith': 18,
#  'family': 71,
#  'freedom': 92,
#  'blessed': 25,
#  'wonderfulwife': 1,
#  'greatkids': 1,
#  'latinotrumper': 1,
#  'god': 167,
#  'veteran': 168,
#  'texas': 35,
#  'single': 1,
#  'navy': 31,
#  'beyhive': 6,
#  'everywoman': 1,
#  'badass': 3,
#  'buckeyes': 4,
#  'gobengals': 1,
#  'thesquadisbig': 1,
#  'momsdemand': 11,
#  'vote': 384,
#  'imwithher': 41,
#  'nevermypresident': 14,
#  'nobannowall': 8,
#  'éireaontaithe': 1,
#  'ynwa': 31,
#  'womanfortrump': 7,
#  'armyfortrump': 51,
#  'leadright': 18,
#  'votetrump': 13,
#  'asktheq': 3,
#  'als': 2,
#  'iconcher': 2,
#  'chercrew': 4,
#  'cher': 4,
#  'legalize': 3,
#  'ndlb2020': 3,
#  'purdue': 3,
#  'boilerup': 4,
#  'christian': 382,
#  'life': 18,
#  'teaparty': 37,
#  'novels': 4,
#  'amwriting': 13,
#  'womenrights': 6,
#  'progressive': 36,
#  'noreligion': 2,
#  'science': 85,
#  'liberal': 47,
#  'animallover': 22,
#  'uniteblue': 84,
#  'uslatino': 2,
#  'getintheway': 2,
#  'educatednastywoman': 4,
#  '8645': 8,
#  'walkaway': 545,
#  'elgringouribista': 2,
#  'magundymaghee': 1,
#  'china': 2,
#  'bot': 2,
#  'djtrumplicans': 1,
#  'trumpknew': 16,
#  'joebidenforpresident2020': 2,
#  'cowboysnation': 14,
#  'makeamericasmartagain': 2,
#  'byedon2020': 17,
#  'goodtrouble': 132,
#  'votebidenharris2020': 48,
#  'lincolnvoter': 27,
#  '45is': 2,
#  'medicare4all': 30,
#  'usaf': 56,
#  'chinaliedpeopledied': 7,
#  'fightevil': 2,
#  'feelingblueinaredstate': 1,
#  'voteblue2020': 184,
#  'exrepublican': 4,
#  'socialismsucks': 7,
#  'rankedballots': 1,
#  'topoli': 2,
#  'onpoli': 1,
#  'books': 20,
#  'music': 48,
#  'amazon': 5,
#  'deadhead': 6,
#  'trumptreason': 13,
#  'foxnewskills': 1,
#  'trumpgenocide': 8,
#  'magatsarecultmembers': 1,
#  'endhumantrafficking': 15,
#  'honduras4trump': 1,
#  'gg33': 8,
#  'dogs': 25,
#  'wall': 4,
#  'persecutedchurch': 1,
#  'jesus': 150,
#  'trumpdigitalarmy': 1,
#  'countrybeforeparty': 10,
#  'prayforrush': 5,
#  'ky': 1,
#  'pray': 10,
#  'trusttheplan': 68,
#  'godwins': 294,
#  'truthandfreedom': 1,
#  'godandcountry': 6,
#  'godblessamerica': 113,
#  'supportourmilitary': 19,
#  'red': 10,
#  'backourleo': 2,
#  'neverforget': 31,
#  'cosproject': 17,
#  'jewishveteransfortrump': 2,
#  'nevertrustademocrat': 2,
#  'withtrumpalltheway': 1,
#  'jailtheswamp': 1,
#  'yahweh': 4,
#  'cult45': 171,
#  'thebestisyettocome': 38,
#  'iammarriedandnotheretodate': 2,
#  'draintheswamp': 488,
#  'umd17': 1,
#  'usc2022': 1,
#  'stopbullying': 4,
#  'stopharassment': 1,
#  'problack': 2,
#  'antiracist': 18,
#  'socialwork': 1,
#  'socialworker': 4,
#  'nyc': 18,
#  '48': 7,
#  'unfit': 9,
#  'trumpliedpeopledied': 18,
#  'trumpmorethenever': 1,
#  'saints': 14,
#  '2ndamendment': 27,
#  'finishthewall': 18,
#  'ridinwithbiden': 79,
#  'gojoe': 53,
#  'gsd': 3,
#  'freegenflynn': 26,
#  'trusttrump': 10,
#  'votebluetosaveamerica': 110,
#  'kaga': 68,
#  'supportourtroops': 44,
#  'semperfi': 22,
#  'ifbap': 65,
#  'magaveteran': 75,
#  'obamagate': 217,
#  'cambma': 4,
#  'build': 22,
#  'starfleet': 2,
#  'startrek': 13,
#  'ds9': 3,
#  'widowsson': 2,
#  'wearestarfleet': 6,
#  'mallermilitia': 2,
#  'vols': 5,
#  'titans': 4,
#  'saveamericavotered': 1,
#  'narcissistabuse': 1,
#  'dem': 11,
#  'saveourcountry': 4,
#  'gopsucks': 1,
#  'republicanshateamerica': 1,
#  'disloyaltotrump': 9,
#  '4ocean': 1,
#  'pence2024': 4,
#  'lgbtfortrump': 1,
#  'chinavirus': 4,
#  'trump2020nowmorethanever': 23,
#  'fourmoreyears': 22,
#  'indyscotforlife': 1,
#  'briansforindy': 2,
#  'dissolovetheunion': 1,
#  'impeach45': 23,
#  'buildthatwall': 18,
#  'vetsbeforeillegals': 6,
#  'kidshelpingourveterans': 1,
#  'scottbaiosarmy': 18,
#  'alllivesmatter': 201,
#  'notmypresident': 198,
#  'trumpresignnow': 11,
#  'trumpworst': 1,
#  'fakechristian': 1,
#  'releaseyourtaxes': 1,
#  'imbleachment': 1,
#  'obamabetterateverything': 1,
#  'mj': 1,
#  'believer': 3,
#  '12202009': 1,
#  'soap': 1,
#  'yr': 2,
#  'patriotsunited': 30,
#  'lgm': 15,
#  'vaquerosahí': 1,
#  'halamadrid': 12,
#  'togetherblue': 7,
#  'iloveamerica': 7,
#  'trumpsucks': 10,
#  'vaccinessavelives': 1,
#  'supportindiefilm': 2,
#  'warrendemocrat': 34,
#  'alwayswithher': 11,
#  'newyorktough': 4,
#  'smarterinspecs': 2,
#  'ethicalvegan': 1,
#  'animalliberation': 1,
#  'abolitionist': 2,
#  'misanthropist': 1,
#  'medicareforall': 64,
#  'greennewdeal': 57,
#  'ubi': 41,
#  'endfracking': 1,
#  'endwars': 1,
#  'stopfundingyemengenocide': 1,
#  'defundpolice': 5,
#  'atheist': 63,
#  'fuckracism': 2,
#  'organize': 4,
#  'cov': 11,
#  'divisivedeplorable': 1,
#  'nothirdway': 1,
#  'petridishlife': 1,
#  'sanders2020': 1,
#  'buildbetterbullshitwithjoe': 1,
#  'votebluenomatterwho': 270,
#  'foryourconsideration': 1,
#  'lgbtq': 250,
#  'impeachtrumpagain': 11,
#  'trumpmoronicplague': 2,
#  'trumpisamoron': 5,
#  'canadacares': 2,
#  'paperballots': 17,
#  'mecfs': 3,
#  'lovethearts': 1,
#  'freedomandequity': 1,
#  'lovestodance': 1,
#  'ibew': 1,
#  'adoptionoption': 1,
#  '1': 196,
#  'mnyga': 2,
#  'landslide': 4,
#  'filmmaker': 8,
#  'gravelraker': 1,
#  'mormon': 2,
#  'jd': 1,
#  'asperger': 2,
#  'desertstormveteran': 2,
#  'venezolanosconbiden': 2,
#  'fuckq': 2,
#  'proudnevertrumper': 4,
#  'maga2020': 318,
#  'country': 28,
#  'istandwiththenra': 1,
#  'rescuedogs': 4,
#  'collegefootball': 3,
#  'womenfortrump': 103,
#  'pizzagate': 8,
#  'strongertogether': 134,
#  'theresistence': 12,
#  'americanwoman': 1,
#  'wwg1wgaworldwide': 45,
#  'qanon': 438,
#  'foreaston': 1,
#  'eastonqpatriot': 2,
#  'anything': 1,
#  'stopthehate': 12,
#  'mypresident': 12,
#  'tdsmuch': 2,
#  'gamecock': 1,
#  'nascar': 16,
#  'braves': 9,
#  'doglover': 6,
#  '400years': 1,
#  '8cantwait': 1,
#  'followthemoney': 10,
#  'maganole': 2,
#  'kagdawg': 2,
#  'azure': 2,
#  'mankind': 1,
#  'godblessusa': 7,
#  'darktolight': 67,
#  'jesusislord': 39,
#  'persisterhood': 1,
#  'victorywaffles': 1,
#  'rebelscum': 8,
#  'keyboardwarriors': 4,
#  'securetheborder': 9,
#  'thankyoubasedgod': 2,
#  'bidenharrislandslide2020': 18,
#  'demcasttx': 17,
#  'teampelosi': 80,
#  'defendthepolice': 18,
#  'boycottchina': 4,
#  'cancelnetflix': 34,
#  'bbqanon': 7,
#  'ptsdsucks': 1,
#  'ld6inaz': 1,
#  'firstweekvoter': 1,
#  'azblue': 2,
#  'yankees': 21,
#  'canadiens': 1,
#  '49ers': 9,
#  'bebest': 41,
#  'digitalsoliderfortrump': 1,
#  'twirling': 3,
#  'october': 3,
#  'autumn': 3,
#  'magical': 3,
#  'pumpkinjiggityjig': 3,
#  'poof': 3,
#  'ettd': 42,
#  'wethepeople': 114,
#  'termlimits': 73,
#  'ally': 27,
#  'killaryforprison': 2,
#  'executetraitorsnow': 2,
#  'patriots': 88,
#  'keepamericasafe': 1,
#  'keepamericafirst': 1,
#  'keepamericaprosperous': 1,
#  'keepamericafree': 2,
#  'keepamericasecure': 1,
#  'constitutionalist': 30,
#  'cubs': 12,
#  'ukcats': 4,
#  'election2020': 20,
#  'democracy': 21,
#  'vetsresistsupportsquadron': 5,
#  'liberty': 43,
#  'faithingod': 1,
#  'pro2a': 30,
#  'wewillvote': 8,
#  'illegitimatepresident': 3,
#  'venezolanoscontrump': 2,
#  'bethehope': 1,
#  'patcot': 4,
#  'haction': 1,
#  'sentinels': 1,
#  'ruleoflaw': 53,
#  'separationofpowers': 1,
#  'votetrump2020': 23,
#  'prochoice': 50,
#  'demvoice1': 26,
#  'fulltimervlife': 1,
#  'neurodivergent': 1,
#  'trumptrain': 300,
#  'trumptheestablisment': 1,
#  'codeofvets': 85,
#  'armyofone': 1,
#  'bolsonaro': 2,
#  'nonewnormal': 5,
#  'saynotobillgates': 1,
#  'geauxtigers': 8,
#  'unacceptable': 1,
#  'fun': 6,
#  'meanman': 2,
#  'covfefeboy': 2,
#  'humanscum': 7,
#  'savagesnowflake': 2,
#  'piano': 2,
#  'vocals': 2,
#  'petetojoe': 4,
#  'dumptrump': 163,
#  'earper': 7,
#  'listersister': 2,
#  'brave': 1,
#  'usmilitary': 10,
#  'meds': 1,
#  'catholic': 88,
#  'married': 28,
#  'medicaladmin': 4,
#  'latinos4trump': 9,
#  'jobsnotmobs': 19,
#  'alwaystrump': 6,
#  'flotus': 20,
#  'joinnra': 1,
#  'backthepolice': 2,
#  'boycottgoodyear': 1,
#  'boycottnetflix': 2,
#  'boycottnfl': 11,
#  'nosocialism': 21,
#  'nosharialaw': 2,
#  'buildthedamnwall': 12,
#  'yoapruebo': 2,
#  'votescience': 6,
#  'indivisibledfw': 1,
#  'actindivisible': 1,
#  'crushms': 1,
#  'republicanwaronwomen': 4,
#  'teamjustice': 57,
#  'wy4djt': 1,
#  'americabebetter': 2,
#  'cspanfan': 3,
#  'travelban': 1,
#  'military': 153,
#  'happyhippiechic': 3,
#  'boricuas4biden': 1,
#  'defundpp': 46,
#  'treasontrump': 1,
#  'twittercensoringmytweets': 1,
#  'yuugetrumpsupporter': 1,
#  'trueconservative': 1,
#  'trump2016': 19,
#  'trumpspeakshismind': 1,
#  'tiredofestablishments': 1,
#  'jail4hillary': 1,
#  'jail4comey': 1,
#  'twitmo': 9,
#  'k': 4,
#  'progressive1leverpullingdem': 2,
#  'voteearly': 50,
#  'trumpcrimecommission': 3,
#  'bluetsunami2020': 52,
#  'bluewavecoming': 4,
#  'constitution': 175,
#  'leo': 40,
#  'generalflynn': 20,
#  'veterans1st': 7,
#  'saveourrepublic': 5,
#  '1nationundergod': 2,
#  'nmexit': 1,
#  'digitalwarrior': 22,
#  'seekjustice': 1,
#  'truthseeker': 17,
#  'banantifa': 1,
#  'banblm': 1,
#  'lawandorder': 67,
#  'voterid': 95,
#  'voteinperson': 20,
#  'usarmy': 17,
#  'blexit': 72,
#  'erased': 3,
#  '88': 7,
#  'jrnation': 4,
#  'clarity': 1,
#  'army': 61,
#  'billclintonisapedo': 1,
#  'fwc': 2,
#  'rvat': 5,
#  'impeachtrump': 102,
#  'defendourdemocracy': 8,
#  'metoo': 163,
#  'trumpsupporter': 26,
#  'votered': 146,
#  'marchfortrump': 1,
#  'tparty': 2,
#  'sgp': 2,
#  'servant': 1,
#  'notmyptesident': 1,
#  'donniedotard': 1,
#  'pizza': 3,
#  'hisnamewassethrich': 5,
#  'freespeech': 55,
#  'fbap': 7,
#  'potus45': 42,
#  'whereshunter': 9,
#  'onev1': 59,
#  'panthers': 1,
#  'caniac': 1,
#  'carolinahurricanes': 1,
#  'gamecocks': 2,
#  'traitorinchief': 4,
#  'trumpvirus': 70,
#  'patriot17': 2,
#  '2nd': 20,
#  'ifbp': 36,
#  'astros': 7,
#  'ftff': 1,
#  'lovelivelife': 1,
#  'cpp': 4,
#  'independent': 43,
#  'filltheseat': 57,
#  'wolastoqiyik': 1,
#  'indigenous': 5,
#  'dj': 2,
#  'weather': 5,
#  'treaty1752': 1,
#  'redpilled': 11,
#  'istandwithflynn': 26,
#  'amerciafirst': 4,
#  'greatawakening': 108,
#  'defendpolice': 9,
#  'eagle': 1,
#  'mcga': 32,
#  'ppc': 13,
#  'influencer': 8,
#  'familytravel': 1,
#  'loveistheonlydancethereis': 1,
#  'eminem': 3,
#  'trumpisracist': 3,
#  'findacure': 2,
#  'freehealthcare': 1,
#  'saveourplanet': 10,
#  'drwho': 1,
#  'llap': 2,
#  'actuallyautistic': 25,
#  'prstrong': 1,
#  'usafirst': 5,
#  'globalismisadisease': 2,
#  'viajero': 1,
#  'sagitario': 1,
#  'bitcoin': 33,
#  'bitcoinstandard': 1,
#  'remember2016': 1,
#  'journalismisdead': 2,
#  'hayuncamino': 1,
#  'yosoyvenezolano': 2,
#  'sjsharks': 4,
#  'grammie': 1,
#  'mom': 31,
#  'bethechange': 8,
#  'gunsafety': 1,
#  'mother': 9,
#  'twitteristheenemy': 2,
#  'basque': 2,
#  'genx': 12,
#  'immarried': 2,
#  'notinterested': 2,
#  'itsmylife': 2,
#  'pardonmyfrench': 2,
#  'thestorm': 26,
#  'deepstate': 14,
#  'votered2020': 33,
#  'th4ever': 1,
#  'brexit': 81,
#  'nopc': 4,
#  'eu': 8,
#  'kbf': 10,
#  'trumparmy': 7,
#  'filmtwitter': 1,
#  'caresist': 2,
#  'nastywoman': 56,
#  'spreadlovenothate': 1,
#  'antiwar': 6,
#  'singlepayer': 7,
#  'wearyourmask': 14,
#  'springsteen': 2,
#  'canpl': 2,
#  'canmnt': 1,
#  'canwnt': 1,
#  'anti': 16,
#  'hongkongneedshelp': 1,
#  'hksos': 1,
#  'truth': 85,
#  'justice': 47,
#  'freeyourmind': 2,
#  'saynotojoe': 3,
#  'progun': 11,
#  'profreedom': 5,
#  'indivisible': 74,
#  'saveourchildren': 196,
#  'chapín': 1,
#  'cubano': 1,
#  'lsualumni': 2,
#  'texan': 15,
#  '17anon': 13,
#  'cult': 6,
#  'trumo2020landslide': 2,
#  'nightshift': 1,
#  'nicunurse': 1,
#  'raabidfun': 1,
#  'familiesbelongtogether': 24,
#  'bringhumanityback': 1,
#  'workatweber': 1,
#  'freepalestine': 62,
#  'gli': 3,
#  'tradwoman': 2,
#  'trump2020landslide': 179,
#  'blueinitiative': 3,
#  'daresists': 1,
#  'geeksresist': 18,
#  'vetsresistsquadron': 21,
#  'ripkaeo': 2,
#  'democrat': 80,
#  'black': 24,
#  'unite': 2,
#  'uk': 5,
#  'gwu': 1,
#  'brotique': 2,
#  'americaortrump': 60,
#  'vote2020': 23,
#  'noelectoralcollege': 1,
#  'smartpeoplewearmasks': 1,
#  'adoptdontshop': 76,
#  'gunreform': 13,
#  'impeachbarr': 25,
#  'marchforourlives': 21,
#  'paperballots2020': 1,
#  'prouddemocrat': 12,
#  'ditchmoscowmitch': 8,
#  'enddaca': 3,
#  'sendthemback': 3,
#  'goldenrule': 4,
#  'patriotsonparler': 3,
#  'recallsisolak': 3,
#  'nvnotpayingpua': 3,
#  'gopokes': 1,
#  'ktbffh': 7,
#  'dodgers': 16,
#  'thunderup': 4,
#  'dabears': 7,
#  'sjw': 6,
#  '4n6rn': 1,
#  'ipv': 1,
#  'healthdisparities': 1,
#  'gender': 2,
#  'nursingresearch': 1,
#  'trumpisanationaldisgrace': 9,
#  'alive': 2,
#  'knower': 2,
#  'proudtexan': 2,
#  'saudi': 1,
#  'boxing': 5,
#  'nba': 5,
#  'mlb': 6,
#  'woke': 14,
#  'greenenergy': 2,
#  'thinblueline': 34,
#  'nralifetimemember': 3,
#  'latinosfortrump': 45,
#  'no_porn': 1,
#  'sustainablewater': 1,
#  'transafricawaterpipeline': 1,
#  'sdgs': 4,
#  'day1trumpteam': 3,
#  'trumpteam': 5,
#  'teamtrudeau': 8,
#  'electmorewomen': 4,
#  'exquisiteaspirationsbroughttofruition': 1,
#  'savethemonarchs': 1,
#  'whovian': 3,
#  'doctorwho': 5,
#  'heismypresident': 4,
#  'potustrump': 7,
#  'weareonehumanrace': 1,
#  'freedomrules': 1,
#  'balance': 2,
#  'seeker': 1,
#  'maskswork': 1,
#  'sonniescorner': 1,
#  'didshesaythat': 1,
#  'ivankatrump2024': 2,
#  'theivanka2024': 2,
#  'keepamericagreat2024': 2,
#  'greatamericancomeback2024': 2,
#  'wearadamnmask': 59,
#  'trumphatesvets': 11,
#  'justice4breonna': 1,
#  'kidsincages': 5,
#  'vegasstronger': 1,
#  'nevertrumper': 52,
#  'meidasmighty': 12,
#  'blacktranslivesmatter': 29,
#  'bilblical': 1,
#  'ues': 1,
#  'uesgays': 1,
#  'nycgays': 1,
#  'hispanicsfortrump': 8,
#  'supportlivingartist': 1,
#  'art': 32,
#  'entertainment': 10,
#  'writing': 9,
#  'artsedu': 1,
#  'artivist': 4,
#  'arts': 7,
#  'culture': 8,
#  'artnews': 1,
#  'media': 10,
#  'harris': 5,
#  'right': 7,
#  'vetsforbiden': 5,
#  'ridadie': 1,
#  'friend': 3,
#  'father': 17,
#  'gpops': 1,
#  'zero': 1,
#  'cheetoesus': 1,
#  'ourfavoritepresident45': 3,
#  'generalstrike': 6,
#  'nomercyfornazis': 1,
#  'fcancer': 2,
#  'believeingod': 1,
#  'proudmom': 3,
#  'proudamerican': 44,
#  'supporttheblue': 5,
#  'weareamericans': 1,
#  'gothright': 1,
#  'joebiden': 48,
#  'kamalaharris': 14,
#  'women': 20,
#  'girls': 3,
#  'equality': 69,
#  'shitforbrains': 1,
#  'soldiers': 1,
#  'crookedjoebiden': 12,
#  'fukouttahere': 1,
#  'bringkaepback': 1,
#  'bbn': 24,
#  'magamoron': 2,
#  'notmeus': 70,
#  'gohawks': 5,
#  'coys': 10,
#  'america': 54,
#  'united': 4,
#  'winning': 63,
#  'cultmember': 1,
#  'change': 3,
#  'brands': 1,
#  'moscowmitchtraitortoamerica': 1,
#  'clublife': 2,
#  'itguysfortrump': 2,
#  'inners': 1,
#  'president': 6,
#  'voteredtosaveamerica': 58,
#  'italexit': 5,
#  'noislam': 3,
#  'lapedofiliaècrimine': 1,
#  'saintsfan': 2,
#  'equalityforall': 20,
#  'freeassange': 39,
#  'ruthless': 3,
#  'photographer': 9,
#  'brewer': 1,
#  'drinksright': 1,
#  'selfacclaimedbeerlover': 1,
#  'teammanunited': 1,
#  'prouddeplorable': 18,
#  'tcot': 91,
#  'benghazi': 35,
#  'jesussaves': 30,
#  'fightlikedomsmom': 1,
#  'ballrags': 2,
#  'boobrags': 2,
#  'ballshades': 2,
#  'baltops': 2,
#  'nederlandsehollywoodvrouwen': 1,
#  'net5': 1,
#  'chiefskingdom': 19,
#  'lgbtqally': 22,
#  'not': 9,
#  'txt_hueningkai': 1,
#  'jisung': 2,
#  'mega': 23,
#  'wmualumni': 2,
#  'advertising': 3,
#  'electwomen': 5,
#  'uruguay': 2,
#  'teamsuperelite': 3,
#  'trumprocks': 6,
#  'neverforgetbenghazi': 5,
#  'buildawallcrimewillfall': 3,
#  'savenyc': 5,
#  'dfrec': 1,
#  'blackvoicesfortrump': 5,
#  'keepamericabeautiful': 2,
#  'keepfloridabeautiful': 1,
#  'binder': 1,
#  'ahcj': 1,
#  'actonclimate': 5,
#  'shutdownfoxnews': 1,
#  'thinkbigsundaywithmarsha': 1,
#  'billionbeers': 1,
#  'nationals': 3,
#  'wizards': 1,
#  'redskins': 1,
#  'httr': 8,
#  'armynationalguard': 2,
#  'barsonly': 1,
#  'woke100': 1,
#  'nre': 1,
#  'redoctober': 7,
#  'operationpaintdrop': 1,
#  'trumpisbroke': 1,
#  'deepfake': 2,
#  'fem2': 1,
#  'me2': 1,
#  'guncontrol': 35,
#  'endsars': 43,
#  'endswat': 4,
#  'abolishpic': 1,
#  'defundpentagon': 1,
#  'wearafuckingmask': 6,
#  'wealthtaxnow': 1,
#  'cancer': 12,
#  'wilder': 1,
#  'fury': 2,
#  'fightlive': 1,
#  'heavyweight': 1,
#  'rosedc11': 1,
#  'yarnellhill': 3,
#  'wildfire': 3,
#  'nmwx': 3,
#  'godbless': 7,
#  'gratitude': 1,
#  'politicaljunkie': 6,
#  'spanishfilipino': 1,
#  'imstillwithher': 39,
#  'endchildtrafficking': 6,
#  'buttigiegdemocrat': 2,
#  'teampeteforever': 25,
#  'lovewins': 19,
#  'iamthenra': 8,
#  'thestormishere': 10,
#  'friarfaithful': 2,
#  '犬好き': 1,
#  'アメリカ在住': 1,
#  '乳がん': 1,
#  'ミュージカル好き': 1,
#  'beardgang': 1,
#  'apexlife': 1,
#  'iqaluit': 1,
#  'stratfordon': 1,
#  'lhr': 1,
#  'gopackgo': 17,
#  '4bid3n': 1,
#  'trumplies': 8,
#  'dukefan4life': 1,
#  'ovo': 1,
#  'ncat21': 1,
#  'teamcavs': 1,
#  'gocards': 1,
#  ...}

# %%
user_descriptions_hastags_dict_sorted = sorted(user_descriptions_hastags_dict.items()
                                               , key=lambda kv: kv[1]
                                               , reverse=True
                                              )
user_descriptions_hastags_dict_sorted
# Out:
# [('maga', 8446),
#  ('kag', 3752),
#  ('trump2020', 3631),
#  ('resist', 3425),
#  ('wwg1wga', 2163),
#  ('blm', 1916),
#  ('blacklivesmatter', 1823),
#  ('bidenharris2020', 1794),
#  ('2a', 1682),
#  ('theresistance', 1072),
#  ('fbr', 1026),
#  ('resistance', 868),
#  ('patriot', 843),
#  ('nra', 825),
#  ('trump', 812),
#  ('prolife', 809),
#  ('voteblue', 757),
#  ('backtheblue', 732),
#  ('kag2020', 717),
#  ('conservative', 657),
#  ('1a', 644),
#  ('buildthewall', 616),
#  ('americafirst', 603),
#  ('walkaway', 545),
#  ('biden2020', 534),
#  ('draintheswamp', 488),
#  ('qanon', 438),
#  ('savethechildren', 390),
#  ('vote', 384),
#  ('bidenharris', 383),
#  ('christian', 382),
#  ('bluewave', 353),
#  ('maga2020', 318),
#  ('fightback', 315),
#  ('trumptrain', 300),
#  ('godwins', 294),
#  ('resister', 291),
#  ('q', 279),
#  ('bluelivesmatter', 278),
#  ('votebluenomatterwho', 270),
#  ('nevertrump', 253),
#  ('lgbtq', 250),
#  ('usa', 220),
#  ('thegreatawakening', 219),
#  ('obamagate', 217),
#  ('bluewave2020', 207),
#  ('alllivesmatter', 201),
#  ('notmypresident', 198),
#  ('1', 196),
#  ('saveourchildren', 196),
#  ('deplorable', 190),
#  ('voteblue2020', 184),
#  ('fucktrump', 180),
#  ('trump2020landslide', 179),
#  ('stillwithher', 177),
#  ('wearamask', 175),
#  ('constitution', 175),
#  ('cult45', 171),
#  ('veteran', 168),
#  ('biden', 167),
#  ('god', 167),
#  ('dumptrump', 163),
#  ('metoo', 163),
#  ('ccot', 162),
#  ('military', 153),
#  ('jesus', 150),
#  ('votered', 146),
#  ('khive', 145),
#  ('vets', 142),
#  ('taketheoath', 136),
#  ('strongertogether', 134),
#  ('goodtrouble', 132),
#  ('digitalsoldier', 120),
#  ('potus', 119),
#  ('israel', 117),
#  ('wethepeople', 114),
#  ('godblessamerica', 113),
#  ('votebluetosaveamerica', 110),
#  ('greatawakening', 108),
#  ('veterans', 108),
#  ('womenfortrump', 103),
#  ('impeachtrump', 102),
#  ('trumppence2020', 100),
#  ('voterid', 95),
#  ('freedom', 92),
#  ('tcot', 91),
#  ('keepamericagreat', 88),
#  ('patriots', 88),
#  ('catholic', 88),
#  ('45', 87),
#  ('demcast', 85),
#  ('science', 85),
#  ('codeofvets', 85),
#  ('truth', 85),
#  ('handmarkedpaperballots', 85),
#  ('climatechange', 84),
#  ('uniteblue', 84),
#  ('neveragain', 84),
#  ('17', 82),
#  ('love', 81),
#  ('brexit', 81),
#  ('teampelosi', 80),
#  ('democrat', 80),
#  ('ridinwithbiden', 79),
#  ('covfefe', 77),
#  ('adoptdontshop', 76),
#  ('usmc', 75),
#  ('magaveteran', 75),
#  ('teamjoe', 75),
#  ('indivisible', 74),
#  ('acab', 74),
#  ('termlimits', 73),
#  ('blexit', 72),
#  ('family', 71),
#  ('trumpvirus', 70),
#  ('notmeus', 70),
#  ('equality', 69),
#  ('trusttheplan', 68),
#  ('kaga', 68),
#  ('pru', 68),
#  ('darktolight', 67),
#  ('lawandorder', 67),
#  ('ifbap', 65),
#  ('makeamericagreatagain', 65),
#  ('medicareforall', 64),
#  ('atheist', 63),
#  ('winning', 63),
#  ('parler', 63),
#  ('freepalestine', 62),
#  ('army', 61),
#  ('feminist', 61),
#  ('fbpe', 61),
#  ('m4a', 61),
#  ('americaortrump', 60),
#  ('vet', 60),
#  ('proisrael', 60),
#  ('countryoverparty', 60),
#  ('yanggang', 59),
#  ('onev1', 59),
#  ('wearadamnmask', 59),
#  ('joebiden2020', 58),
#  ('voteredtosaveamerica', 58),
#  ('pro', 58),
#  ('flipthesenate', 57),
#  ('greennewdeal', 57),
#  ('teamjustice', 57),
#  ('filltheseat', 57),
#  ('molonlabe', 57),
#  ('rightmatters', 56),
#  ('usaf', 56),
#  ('nastywoman', 56),
#  ('freespeech', 55),
#  ('politics', 54),
#  ('america', 54),
#  ('digitalsoldiers', 54),
#  ('truthmatters', 54),
#  ('gojoe', 53),
#  ('ruleoflaw', 53),
#  ('nationalist', 53),
#  ('abolishice', 53),
#  ('qarmy', 53),
#  ('lgbt', 52),
#  ('bluetsunami2020', 52),
#  ('nevertrumper', 52),
#  ('climatechangeisreal', 52),
#  ('armyfortrump', 51),
#  ('humanrights', 51),
#  ('prochoice', 50),
#  ('voteearly', 50),
#  ('istandwithisrael', 50),
#  ('ingodwetrust', 49),
#  ('votehimout', 49),
#  ('fakenews', 48),
#  ('votebidenharris2020', 48),
#  ('music', 48),
#  ('joebiden', 48),
#  ('wtp2020', 48),
#  ('loveislove', 47),
#  ('liberal', 47),
#  ('justice', 47),
#  ('vetsagainsttrump', 47),
#  ('gop', 46),
#  ('peace', 46),
#  ('defundpp', 46),
#  ('votebidenharris', 46),
#  ('trumplandslide2020', 46),
#  ('wwg1wgaworldwide', 45),
#  ('latinosfortrump', 45),
#  ('postcardstovoters', 45),
#  ('supportourtroops', 44),
#  ('proudamerican', 44),
#  ('liberty', 43),
#  ('independent', 43),
#  ('endsars', 43),
#  ('antifa', 43),
#  ('writer', 43),
#  ('μολωνλαβε', 42),
#  ('ettd', 42),
#  ('potus45', 42),
#  ('fbts', 42),
#  ('climateaction', 42),
#  ('imwithher', 41),
#  ('ubi', 41),
#  ('bebest', 41),
#  ('liberalismisamentaldisorder', 41),
#  ('climatecrisis', 41),
#  ('nojusticenopeace', 41),
#  ('leo', 40),
#  ('riprbg', 40),
#  ('trumprussia', 40),
#  ('antifascist', 40),
#  ('persist', 40),
#  ('jesusislord', 39),
#  ('freeassange', 39),
#  ('imstillwithher', 39),
#  ('rolltide', 39),
#  ('wakeupamerica', 39),
#  ('trump2020landslidevictory', 39),
#  ('vegan', 39),
#  ('resisters', 38),
#  ('american', 38),
#  ('thebestisyettocome', 38),
#  ('moscowmitch', 38),
#  ('ifb', 38),
#  ('rbg', 38),
#  ('ridenwithbiden', 38),
#  ('bluetsunami', 37),
#  ('teaparty', 37),
#  ('themighty200', 37),
#  ('animalrights', 37),
#  ('2', 37),
#  ('votebiden', 37),
#  ('progressive', 36),
#  ('ifbp', 36),
#  ('ditchmitch', 36),
#  ('impeach', 36),
#  ('texas', 35),
#  ('benghazi', 35),
#  ('guncontrol', 35),
#  ('trump2q2q', 35),
#  ('republican', 35),
#  ('presidenttrump', 35),
#  ('exgop', 35),
#  ('warrendemocrat', 34),
#  ('cancelnetflix', 34),
#  ('thinblueline', 34),
#  ('tre45on', 34),
#  ('mufc', 34),
#  ('removetrump', 34),
#  ('sethrich', 34),
#  ('genflynn', 34),
#  ('votebymail', 34),
#  ('freeflynn', 34),
#  ('bitcoin', 33),
#  ('votered2020', 33),
#  ('redpill', 33),
#  ('turntexasblue', 33),
#  ('traitortrump', 33),
#  ('twitterphilanthropy', 33),
#  ('defundthepolice', 33),
#  ('daca', 33),
#  ('mcga', 32),
#  ('art', 32),
#  ('travel', 32),
#  ('gnd', 32),
#  ('maskup', 32),
#  ('factsmatter', 32),
#  ('votebluedownballot', 32),
#  ('votebluetoendthisnightmare', 32),
#  ('stayhome', 32),
#  ('navy', 31),
#  ('ynwa', 31),
#  ('neverforget', 31),
#  ('mom', 31),
#  ('takeaknee', 31),
#  ('twgrp', 31),
#  ('medicare4all', 30),
#  ('patriotsunited', 30),
#  ('constitutionalist', 30),
#  ('pro2a', 30),
#  ('jesussaves', 30),
#  ('lockherup', 30),
#  ('gunsense', 30),
#  ('usn', 30),
#  ('pridefamily', 30),
#  ('blacktranslivesmatter', 29),
#  ('followback', 29),
#  ('bekind', 29),
#  ('freerealitywinner', 29),
#  ('flyeaglesfly', 28),
#  ('news', 28),
#  ('country', 28),
#  ('married', 28),
#  ('bernie2020', 28),
#  ('bidenharris2020landslide', 28),
#  ('artist', 28),
#  ('bansharia', 28),
#  ('veteransagainsttrump', 28),
#  ('climate', 28),
#  ('autism', 28),
#  ('libertarian', 27),
#  ('proud', 27),
#  ('lincolnvoter', 27),
#  ('2ndamendment', 27),
#  ('ally', 27),
#  ('lfc', 27),
#  ('magats', 27),
#  ('america1st', 27),
#  ('istandwithtrump', 27),
#  ('trumpmustgo', 27),
#  ('unitedwestand', 27),
#  ('americaworkstogether', 27),
#  ('freegenflynn', 26),
#  ('demvoice1', 26),
#  ('trumpsupporter', 26),
#  ('istandwithflynn', 26),
#  ('thestorm', 26),
#  ('instablock', 26),
#  ('blue', 26),
#  ('teamtrump', 26),
#  ('health', 26),
#  ('cruzcrew', 26),
#  ('author', 26),
#  ('guncontrolnow', 26),
#  ('closethecamps', 25),
#  ('blessed', 25),
#  ('dogs', 25),
#  ('actuallyautistic', 25),
#  ('impeachbarr', 25),
#  ('teampeteforever', 25),
#  ('election2016', 25),
#  ('activist', 25),
#  ('lakers', 25),
#  ('fbrparty', 25),
#  ('familiesbelongtogether', 24),
#  ('black', 24),
#  ('bbn', 24),
#  ('resisttrump', 24),
#  ('resistor', 24),
#  ('buildbackbetter', 24),
#  ('teampatriot', 24),
#  ('2020', 24),
#  ('flipthesenateblue', 24),
#  ('goblue', 24),
#  ('trudeaumustgo', 24),
#  ('photography', 24),
#  ('savetheusps', 23),
#  ('nomasks', 23),
#  ('trump2020nowmorethanever', 23),
#  ('impeach45', 23),
#  ('votetrump2020', 23),
#  ('vote2020', 23),
#  ('mega', 23),
#  ('actor', 23),
#  ('lsu', 23),
#  ('steelers', 23),
#  ('capitalism', 23),
#  ('blueout', 23),
#  ('deplorables', 23),
#  ('4moreyears', 23),
#  ('forthepeople', 23),
#  ('standwithhongkong', 23),
#  ('wearethenewsnow', 23),
#  ('demcastca', 23),
#  ('legalizeit', 23),
#  ('animallover', 22),
#  ('semperfi', 22),
#  ('build', 22),
#  ('fourmoreyears', 22),
#  ('digitalwarrior', 22),
#  ('lgbtqally', 22),
#  ('votethemout', 22),
#  ('teampete', 22),
#  ('husband', 22),
#  ('inittogether', 22),
#  ('teambiden', 22),
#  ('justiceiscoming', 22),
#  ('trumpresign', 22),
#  ('keeptexasred', 22),
#  ('yankees', 21),
#  ('democracy', 21),
#  ('nosocialism', 21),
#  ('vetsresistsquadron', 21),
#  ('marchforourlives', 21),
#  ('billsmafia', 21),
#  ('environment', 21),
#  ('lakeshow', 21),
#  ('womensrights', 21),
#  ('bidenharristosaveamerica', 21),
#  ('msm', 21),
#  ('era', 21),
#  ('wherearethechildren', 21),
#  ('entrepreneur', 20),
#  ('books', 20),
#  ('election2020', 20),
#  ('flotus', 20),
#  ('generalflynn', 20),
#  ('voteinperson', 20),
#  ('2nd', 20),
#  ('women', 20),
#  ('equalityforall', 20),
#  ('humanityfirst', 20),
#  ('trumpismypresident', 20),
#  ('6', 20),
#  ('allblacklivesmatter', 20),
#  ('usnavy', 20),
#  ('repealsection230', 20),
#  ('enoughisenough', 20),
#  ('cue', 20),
#  ('covid19', 20),
#  ('pride', 20),
#  ('godfirst', 20),
#  ('rn', 20),
#  ('ptsd', 20),
#  ('gunreformnow', 20),
#  ('obama', 19),
#  ('supportourmilitary', 19),
#  ('jobsnotmobs', 19),
#  ('trump2016', 19),
#  ('chiefskingdom', 19),
#  ('lovewins', 19),
#  ('raidernation', 19),
#  ('impotus', 19),
#  ('bts', 19),
#  ('redwave', 19),
#  ('lockhimup', 19),
#  ('demexit', 19),
#  ('saveusps', 19),
#  ('i', 19),
#  ('fitness', 19),
#  ('education', 19),
#  ('kaga2020', 19),
#  ('antitrump', 19),
#  ('btc', 19),
#  ('retired', 19),
#  ('benghaziaintgoingaway', 19),
#  ('bendedknee', 19),
#  ('democrats', 19),
#  ('cancersucks', 19),
#  ('restart_opposition', 19),
#  ('deletefacebook', 19),
#  ('mma', 18),
#  ('tech', 18),
#  ('faith', 18),
#  ('leadright', 18),
#  ('life', 18),
#  ('antiracist', 18),
#  ('nyc', 18),
#  ('trumpliedpeopledied', 18),
#  ('finishthewall', 18),
#  ('buildthatwall', 18),
#  ('scottbaiosarmy', 18),
#  ('bidenharrislandslide2020', 18),
#  ('defendthepolice', 18),
#  ('geeksresist', 18),
#  ('prouddeplorable', 18),
#  ('nurse', 18),
#  ('trumpliespeopledie', 18),
#  ('no', 18),
#  ('dumptrump2020', 18),
#  ('pjnet', 18),
#  ('proudresister', 18),
#  ('seahawks', 18),
#  ('notabot', 18),
#  ('usconstitution', 18),
#  ('healthcare', 18),
#  ('votethemallout', 18),
#  ('lovemypresident', 18),
#  ('mighty200', 18),
#  ('socialjustice', 17),
#  ('sports', 17),
#  ('byedon2020', 17),
#  ('cosproject', 17),
#  ('paperballots', 17),
#  ('demcasttx', 17),
#  ('truthseeker', 17),
#  ('usarmy', 17),
#  ('father', 17),
#  ('gopackgo', 17),
#  ('trump2020tosaveamerica', 17),
#  ('crypto', 17),
#  ('louis', 17),
#  ('chooselife', 17),
#  ('gbr', 17),
#  ('translivesmatter', 17),
#  ('shepersisted', 17),
#  ('ivoted', 17),
#  ('neverbernie', 17),
#  ('spoonie', 17),
#  ('commonsense', 17),
#  ('starwars', 17),
#  ('istandwithtrudeau', 17),
#  ('istandwithgenflynn', 17),
#  ('wearethepatriots', 17),
#  ('sfgiants', 17),
#  ('magaa', 17),
#  ('walkawayfromdemocrats', 17),
#  ('the', 17),
#  ('spygate', 17),
#  ('endcitizensunited', 17),
#  ('poet', 17),
#  ('trump4eva', 17),
#  ('neverbiden', 17),
#  ('vetsresist', 17),
#  ('donaldtrump', 17),
#  ('rbgrevolution', 17),
#  ('impeachthemf', 17),
#  ('tgdn', 17),
#  ('bluenomatterwho', 16),
#  ('nodms', 16),
#  ('mmiw', 16),
#  ('patriotsunite', 16),
#  ('votetrumpout', 16),
#  ('presidentbiden', 16),
#  ('trumpknew', 16),
#  ('nascar', 16),
#  ('anti', 16),
#  ('dodgers', 16),
#  ('stayathome', 16),
#  ('confirmacb', 16),
#  ('nodaca', 16),
#  ('girldad', 16),
#  ('dad', 16),
#  ('demforce', 16),
#  ('wehaveherback', 16),
#  ('prayforamerica', 16),
#  ('autismawareness', 16),
#  ('miga', 16),
#  ('standwithisrael', 16),
#  ('bds', 16),
#  ('cancersurvivor', 16),
#  ('wtpblue', 16),
#  ('trumpisatraitor', 16),
#  ('lgbtqia', 16),
#  ('marketing', 16),
#  ('flynn', 16),
#  ('wife', 16),
#  ('votelikeblackwomen', 16),
#  ('votebiden2020', 16),
#  ('onenationundergod', 16),
#  ('shewon', 15),
#  ('endhumantrafficking', 15),
#  ('lgm', 15),
#  ('texan', 15),
#  ('foodie', 15),
#  ('whodat', 15),
#  ('happilymarried', 15),
#  ('jesusisking', 15),
#  ('netneutrality', 15),
#  ('unitednotdivided', 15),
#  ('outlander', 15),
#  ('cybersecurity', 15),
#  ('protrump', 15),
#  ('banassaultweapons', 15),
#  ('humanist', 15),
#  ('xrp', 15),
#  ('history', 15),
#  ('3stars4genflynn', 15),
#  ('women4trump', 15),
#  ('lockthemup', 15),
#  ('animals', 15),
#  ('survivor', 15),
#  ('alm', 15),
#  ('ados', 15),
#  ('timesup', 15),
#  ('womenagainsttrump', 15),
#  ('washyourhands', 15),
#  ('magadragtheinterstate', 15),
#  ('resisting', 15),
#  ('anon', 15),
#  ('ufc', 14),
#  ('savetheplanet', 14),
#  ('nevermypresident', 14),
#  ('cowboysnation', 14),
#  ('saints', 14),
#  ('deepstate', 14),
#  ('wearyourmask', 14),
#  ('woke', 14),
#  ('kamalaharris', 14),
#  ('police', 14),
#  ('endthefed', 14),
#  ('harry', 14),
#  ('climateemergency', 14),
#  ('livefreeordie', 14),
#  ('twd', 14),
#  ('wtp', 14),
#  ('byedon', 14),
#  ('redwaverising', 14),
#  ('innovation', 14),
#  ('georgefloyd', 14),
#  ('cowboys', 14),
#  ('skol', 14),
#  ('fuckcancer', 14),
#  ('dts', 14),
#  ('irish', 14),
#  ('justiceforgeorgefloyd', 14),
#  ('freethinker', 14),
#  ('midnightrider', 14),
#  ('votejoebiden', 14),
#  ('boycottnra', 14),
#  ('ai', 14),
#  ('mentalhealth', 14),
#  ('trumpliesamericansdie', 14),
#  ('socialmedia', 14),
#  ('cyrus_i', 14),
#  ('impeachedforlife', 14),
#  ('clearflynnnow', 14),
#  ('landslide2020', 14),
#  ('fresh', 13),
#  ('patriotsfight', 13),
#  ('votetrump', 13),
#  ('amwriting', 13),
#  ('trumptreason', 13),
#  ('startrek', 13),
#  ('ppc', 13),
#  ('17anon', 13),
#  ('gunreform', 13),
#  ('teamfollowback', 13),
#  ('chelseafc', 13),
#  ('dubnation', 13),
#  ('qvarmy', 13),
#  ('justiceforbreonnataylor', 13),
#  ('intj', 13),
#  ('nramember', 13),
#  ('cueanon', 13),
#  ('wallofvets', 13),
#  ('writingcommunity', 13),
#  ('joe2020', 13),
#  ('stopthebias', 13),
#  ('followbackresistance', 13),
#  ('singer', 13),
#  ('endthenightmare', 13),
#  ('freehongkong', 13),
#  ('wwg1wga_worldwide', 13),
#  ('v4cr', 13),
#  ('swat', 13),
#  ('sussexsquad', 13),
#  ('ripgop', 13),
#  ('cos', 13),
#  ('lockthemallup', 13),
#  ('demcastor', 13),
#  ('infj', 13),
#  ('standfortheflag', 13),
#  ('lincolnproject', 13),
#  ('proudliberal', 13),
#  ('wakeup', 13),
#  ('trumpcrimefamily', 13),
#  ('benotafraid', 13),
#  ('nfl', 12),
#  ('halamadrid', 12),
#  ('theresistence', 12),
#  ('stopthehate', 12),
#  ('mypresident', 12),
#  ('cubs', 12),
#  ('buildthedamnwall', 12),
#  ('genx', 12),
#  ('prouddemocrat', 12),
#  ('meidasmighty', 12),
#  ('crookedjoebiden', 12),
#  ('cancer', 12),
#  ('ω', 12),
#  ('bluewave2018', 12),
#  ('3', 12),
#  ('drainthedeepstate', 12),
#  ('plandemic', 12),
#  ('cats', 12),
#  ('cfc', 12),
#  ('ltc', 12),
#  ('freeiran', 12),
#  ('saveamerica', 12),
#  ('lnyhbt', 12),
#  ('golf', 12),
#  ('jesuschrist', 12),
#  ('bestpresidentever', 12),
#  ('business', 12),
#  ('supernatural', 12),
#  ('breonnataylor', 12),
#  ('packers', 12),
#  ('freedomofspeech', 12),
#  ('arsenal', 12),
#  ('maga2020landslide', 12),
#  ('rejoineu', 12),
#  ('sciencematters', 12),
#  ('corruption', 12),
#  ('hope', 12),
#  ('gopats', 12),
#  ('orangeupfortrump', 12),
#  ('coffee', 12),
#  ('goptraitors', 12),
#  ('chronicpain', 12),
#  ('voterfraud', 12),
#  ('acb', 12),
#  ('twitter', 12),
#  ('dar', 12),
#  ('lexit', 12),
#  ('lgbtqrights', 12),
#  ('gotv', 12),
#  ('armyvet', 12),
#  ('noamnesty', 12),
#  ('veteransfortrump', 12),
#  ('neverhillary', 12),
#  ('hookem', 12),
#  ('restartmiga', 12),
#  ('corruptgop', 12),
#  ('war', 12),
#  ('navyvet', 12),
#  ('believe', 12),
#  ('civilrights', 12),
#  ('geek', 11),
#  ('momsdemand', 11),
#  ('dem', 11),
#  ('trumpresignnow', 11),
#  ('alwayswithher', 11),
#  ('cov', 11),
#  ('impeachtrumpagain', 11),
#  ('boycottnfl', 11),
#  ('redpilled', 11),
#  ('progun', 11),
#  ('trumphatesvets', 11),
#  ('25thamendmentnow', 11),
#  ('yanggangforever', 11),
#  ('votejoe', 11),
#  ('ice', 11),
#  ('sot', 11),
#  ('enjoytheshow', 11),
#  ('leos', 11),
#  ('nolists', 11),
#  ('vfl', 11),
#  ('redamlo', 11),
#  ('enough', 11),
#  ('realdonaldtrump', 11),
#  ('silentnomore', 11),
#  ('pedogate', 11),
#  ('liarinchief', 11),
#  ('geoengineering', 11),
#  ('trump2020kag', 11),
#  ('lovetrumpshate', 11),
#  ('noafd', 11),
#  ('riseup', 11),
#  ('goodvsevil', 11),
#  ('humanity', 11),
#  ('vegetarian', 11),
#  ('firstresponders', 11),
#  ('savedemocracy', 11),
#  ('godblesspresidenttrump', 11),
#  ('cannabis', 11),
#  ('fillthatseat', 11),
#  ('sheepnomore', 11),
#  ('resistersister', 11),
#  ('recallgavinnewsom', 11),
#  ('save', 11),
#  ('oathkeeper', 11),
#  ('endracism', 11),
#  ('impeachedforever', 11),
#  ('resistancetaskforce', 11),
#  ('syria', 11),
#  ('demcastfl', 11),
#  ('fakepresident', 11),
#  ('gobuckeyes', 11),
#  ('solidarity', 11),
#  ('neverbidennevertrump', 11),
#  ('100', 11),
#  ('socialismkills', 10),
#  ('votevets', 10),
#  ('countrybeforeparty', 10),
#  ('pray', 10),
#  ('red', 10),
#  ('trusttrump', 10),
#  ('trumpsucks', 10),
#  ('followthemoney', 10),
#  ('usmilitary', 10),
#  ('saveourplanet', 10),
#  ('kbf', 10),
#  ('entertainment', 10),
#  ('media', 10),
#  ('coys', 10),
#  ('thestormishere', 10),
#  ('mffl', 10),
#  ('bacon', 10),
#  ('teacher', 10),
#  ('follow', 10),
#  ('saytheirnames', 10),
#  ('veteransfirst', 10),
#  ('democratshateamerica', 10),
#  ('all', 10),
#  ('redsox', 10),
#  ('donthecon', 10),
#  ('homeschool', 10),
#  ('eranow', 10),
#  ('wewantjoe', 10),
#  ('covid', 10),
#  ('trump45', 10),
#  ('proamerica', 10),
#  ('aclu', 10),
#  ('mambamentality', 10),
#  ('blockedbytrump', 10),
#  ('goducks', 10),
#  ('icantbreathe', 10),
#  ('freepress', 10),
#  ('support', 10),
#  ('godblesstheusa', 10),
#  ('lfg', 10),
#  ('jobs', 10),
#  ('horror', 10),
#  ('h2p', 10),
#  ('mybodymychoice', 10),
#  ('fdt', 10),
#  ('scotus', 10),
#  ('ripcity', 10),
#  ('takeourcountryback', 10),
#  ('unions', 10),
#  ('walkedaway', 10),
#  ('blockchain', 10),
#  ('nsfw', 10),
#  ('iii', 10),
#  ('jexit', 10),
#  ('abortionismurder', 10),
#  ('kamala2020', 10),
#  ('bidenforpresident', 10),
#  ('shadowbanned', 10),
#  ('loveusa', 10),
#  ('trumptrain2020', 10),
#  ('spaceforce', 10),
#  ('rescue', 10),
#  ('mag', 10),
#  ('putinspuppet', 10),
#  ('veteransresist', 10),
#  ('resistersunite', 10),
#  ('apruebo', 10),
#  ('itmfa', 10),
#  ('defenddaca', 10),
#  ('restartleader', 10),
#  ('betocrat', 10),
#  ('americanpatriot', 9),
#  ('wwe', 9),
#  ('unfit', 9),
#  ('disloyaltotrump', 9),
#  ('braves', 9),
#  ('securetheborder', 9),
#  ('49ers', 9),
#  ('latinos4trump', 9),
#  ('twitmo', 9),
#  ('whereshunter', 9),
#  ('defendpolice', 9),
#  ('mother', 9),
#  ('trumpisanationaldisgrace', 9),
#  ('writing', 9),
#  ('photographer', 9),
#  ('not', 9),
#  ('herewego', 9),
#  ('movies', 9),
#  ('finance', 9),
#  ('spnfamily', 9),
#  ('humor', 9),
#  ('constitutionalconservative', 9),
#  ('bb22', 9),
#  ('stopthecoup', 9),
#  ('wintheera', 9),
#  ('basta', 9),
#  ('venezuela', 9),
#  ('hannity', 9),
#  ('stlcards', 9),
#  ('allcaps', 9),
#  ('joebidenissick', 9),
#  ('impeachtrumpnow', 9),
#  ('daviddorn', 9),
#  ('socialist', 9),
#  ('waar', 9),
#  ('endgunviolence', 9),
#  ('firefighter', 9),
#  ('sovereignty', 9),
#  ('trumpforprison', 9),
#  ('unkochamerica', 9),
#  ('sayhername', 9),
#  ('marine', 9),
#  ('comics', 9),
#  ('saveaca', 9),
#  ('deportthemall', 9),
#  ('anonymous', 9),
#  ('nature', 9),
#  ('onevoice1', 9),
#  ('flynnfighters', 9),
#  ('allin', 9),
#  ('rechazo', 9),
#  ('biden2020landslide', 9),
#  ('blue2020', 9),
#  ('ravensflock', 9),
#  ('keeppounding', 9),
#  ('redtsunami', 9),
#  ('biker', 9),
#  ('goa', 9),
#  ('jesusmatters', 9),
#  ('digital', 9),
#  ('unionstrong', 9),
#  ('liberalismisamentaldisease', 9),
#  ('desertstorm', 9),
#  ('healthcareforall', 9),
#  ('4a', 9),
#  ('disabled', 9),
#  ('navyveteran', 9),
#  ('stopislam', 9),
#  ('s', 9),
#  ('nocommunism', 9),
#  ('armymom', 9),
#  ('constitutional', 9),
#  ('steelernation', 9),
#  ('gay', 9),
#  ('22aday', 9),
#  ('qsentme', 9),
#  ('chicago', 9),
#  ('bidenriots', 9),
#  ('istandfortheflag', 9),
#  ('gojoe2020', 9),
#  ('equalrights', 9),
#  ('proudpatriot', 9),
#  ('votebidentosaveamerica', 9),
#  ('demcastsc', 9),
#  ('godalwayswins', 9),
#  ('promisesmadepromiseskept', 9),
#  ('lbgtq', 9),
#  ('educator', 9),
#  ('uscg', 9),
#  ('tds', 9),
#  ('kamalaharrisvp', 9),
#  ('waterislife', 9),
#  ('fam46', 9),
#  ('latina', 9),
#  ('americanexceptionalism', 9),
#  ('ms', 9),
#  ('teamgod', 9),
#  ('backblue', 9),
#  ('kamala', 9),
#  ('nyy', 8),
#  ('clemson', 8),
#  ('snowflake', 8),
#  ('kindness', 8),
#  ('unity', 8),
#  ('nobannowall', 8),
#  ('8645', 8),
#  ('trumpgenocide', 8),
#  ('gg33', 8),
#  ('filmmaker', 8),
#  ('pizzagate', 8),
#  ('rebelscum', 8),
#  ('wewillvote', 8),
#  ('geauxtigers', 8),
#  ('defendourdemocracy', 8),
#  ('influencer', 8),
#  ('bethechange', 8),
#  ('eu', 8),
#  ('ditchmoscowmitch', 8),
#  ('teamtrudeau', 8),
#  ('hispanicsfortrump', 8),
#  ('culture', 8),
#  ('httr', 8),
#  ('iamthenra', 8),
#  ('trumplies', 8),
#  ('covidiots', 8),
#  ('youtuber', 8),
#  ('journalist', 8),
#  ('jfkjrlives', 8),
#  ('noracism', 8),
#  ('lovetrump', 8),
#  ('yang2024', 8),
#  ('savetherepublic', 8),
#  ('oann', 8),
#  ('armorofgod', 8),
#  ('ifollowback', 8),
#  ('nolist', 8),
#  ('hailstate', 8),
#  ('wwg1wwga', 8),
#  ('armyveteran', 8),
#  ('trumplandslide', 8),
#  ('insulin4all', 8),
#  ('mets', 8),
#  ('fibro', 8),
#  ('trumpisaracist', 8),
#  ('injustice', 8),
#  ('forgodandcountry', 8),
#  ('startups', 8),
#  ('greenparty', 8),
#  ('multiplesclerosis', 8),
#  ('yang2020', 8),
#  ('awake', 8),
#  ('mambaforever', 8),
#  ('diversity', 8),
#  ('werespectvets', 8),
#  ('votebluetosaveamerica2020', 8),
#  ('nhl', 8),
#  ('justiceisontheballot', 8),
#  ('traitor', 8),
#  ('russianbot', 8),
#  ('9', 8),
#  ('navymom', 8),
#  ('jesusfirst', 8),
#  ('savethechildrenworldwide', 8),
#  ('familyiseverything', 8),
#  ('defeattrump', 8),
#  ('voiceactor', 8),
#  ('food', 8),
#  ...]

# %%
user_descriptions_hastags_dict_sorted[:20]
# Out:
# [('maga', 8446),
#  ('kag', 3752),
#  ('trump2020', 3631),
#  ('resist', 3425),
#  ('wwg1wga', 2163),
#  ('blm', 1916),
#  ('blacklivesmatter', 1823),
#  ('bidenharris2020', 1794),
#  ('2a', 1682),
#  ('theresistance', 1072),
#  ('fbr', 1026),
#  ('resistance', 868),
#  ('patriot', 843),
#  ('nra', 825),
#  ('trump', 812),
#  ('prolife', 809),
#  ('voteblue', 757),
#  ('backtheblue', 732),
#  ('kag2020', 717),
#  ('conservative', 657)]

# %% [markdown]
# ## Popular hastags in full_text

# %%
full_text_hastags = df.full_text.apply(lambda x: re.findall(r"#(\w+)", x))
type(full_text_hastags)
# Out:
# pandas.core.series.Series

# %%
full_text_hastags[2][1].lower()
# Out:
# '2020debate'

# %%
full_text_hastags_dict = {}
for x in full_text_hastags:
    for y in x:
        if y.lower() in full_text_hastags_dict:
            full_text_hastags_dict[y.lower()] += 1
        else:
            full_text_hastags_dict[y.lower()] = 1

# %%
full_text_hastags_dict
# Out:
# {'presidentialdebate': 307,
#  'debates2020': 2085,
#  'trumpisanationaldisgrace': 24,
#  'varneyco': 2,
#  '2020debate': 30,
#  'truckers4trump': 7,
#  'maduronuestravozenlaonu': 1,
#  'trump2020': 493,
#  'bidensshitstorm': 1,
#  'debatetuesday': 36,
#  'presidentialdebate2020': 173,
#  'byerudy': 13,
#  'sleepyjoe': 26,
#  'crookedhillary': 6,
#  'debate': 156,
#  'trump': 675,
#  'trum': 7,
#  'maga': 428,
#  'trumptrain2020': 4,
#  'aag': 4,
#  'aag2020': 4,
#  'jornaldarecord': 2,
#  'jr24h': 2,
#  'jornaldacultura': 1,
#  'argentinasupportstrump': 26,
#  'trumppence2020': 21,
#  'debate2020': 181,
#  'biden': 281,
#  'hawkins': 4,
#  'jorgensen': 4,
#  'yacpolls': 4,
#  'elecciones2020': 6,
#  'white': 3,
#  'joebidenkamalaharris2020': 6,
#  'bidenharrislandslide2020': 21,
#  'ballotharvesting': 16,
#  'trumpcrimefamily': 26,
#  'taxes': 3,
#  'irs': 3,
#  'americaortrump': 21,
#  'liarinchief': 15,
#  'grifterinchief': 1,
#  'scotus': 16,
#  'bidenharristosaveamerica': 26,
#  'nyt': 4,
#  'trumpvirus': 77,
#  'bidenvstrump': 3,
#  'trumpmeltdown': 163,
#  'adderall': 1,
#  'taxreturns': 3,
#  'covid19': 511,
#  'keepamericagreat': 28,
#  'armyfortrump': 19,
#  'trump2020landslide': 44,
#  'kidvicious': 5,
#  'fucktrump': 12,
#  'senate': 2,
#  'supremecourtjustice': 1,
#  'trumptaxreturns': 25,
#  'trumpisbroke': 11,
#  'peterson': 1,
#  'utdebates': 1,
#  'primerdebate': 3,
#  'joebiden': 200,
#  'altmys': 1,
#  'trumpprojection': 1,
#  'stoptrumpselectiontheft': 4,
#  'billbarr': 4,
#  'redwave2020': 3,
#  'new': 23,
#  'empathy': 6,
#  'whatunitesus': 5,
#  'bimboeruption': 1,
#  'freshresists': 1,
#  'harvest': 1,
#  'yahuah': 1,
#  'ridingwithbiden': 1,
#  'byedon': 3,
#  'oann': 19,
#  'nzdusd': 1,
#  'wakeupamerica': 20,
#  'mundo': 5,
#  'internacional': 5,
#  'eeuu': 28,
#  'quintopoder': 1,
#  'windivisible': 2,
#  'republicans': 11,
#  'aca': 4,
#  'retweet': 3,
#  'pleaseretweet': 1,
#  'vote': 350,
#  'votethemallout2020': 2,
#  'makeamericadecentagain': 1,
#  'walkaway': 22,
#  'londonleads': 1,
#  'rankedballots': 1,
#  'breaking': 68,
#  'alternativapopularrevolucionaria': 1,
#  'psuv': 1,
#  'gallosdemonagas': 1,
#  'votapcv': 1,
#  'trumpprisontreason': 1,
#  'smartnews': 42,
#  'biafraexit': 1,
#  'biafrafreedom': 2,
#  'checkjoesears': 9,
#  'basementjoe': 1,
#  'votebluetoendthisnightmare': 33,
#  'politics': 13,
#  'corruption': 10,
#  'presidentialdebate20': 1,
#  'twdfamily': 1,
#  'lauraloomerlandslide': 1,
#  'eargate': 1,
#  'whereshunter': 9,
#  'msnbc': 14,
#  'p': 11,
#  'turntexasblue': 18,
#  'debates': 266,
#  'chucktoddiseldiablo': 1,
#  'トランプ大統領': 3,
#  'kamalapayshertaxes': 1,
#  'kamalaharrisvp': 3,
#  'kamalaharris': 10,
#  'canada': 5,
#  'gymjordan': 15,
#  'gymjordanknew': 8,
#  'dnc': 9,
#  'checkjoeseyepupils': 1,
#  'trumpdementia': 1,
#  'maga2020': 66,
#  'maga2020landslide': 3,
#  'envideo': 5,
#  'fightback': 12,
#  'twudebate': 1,
#  'trumplies': 9,
#  'bidenharris2020': 183,
#  'presiden': 2,
#  'cle': 1,
#  'joetheliar': 1,
#  'hallelujah': 2,
#  'bidenharris2020tosaveamerica': 18,
#  'movetrumpout': 3,
#  'donaldtrump': 150,
#  'clevelan': 1,
#  'wtf': 3,
#  'vot': 5,
#  'supernecessary': 2,
#  'letherspeak': 4,
#  'letherdebate': 3,
#  'jojorgensen2020': 2,
#  'fakedebates': 4,
#  'fakedebate': 1,
#  'debatemayhem': 1,
#  'votegold2020': 2,
#  'consequences': 1,
#  'bidennobelpeaceprize': 1,
#  'cleveland': 7,
#  'florida': 11,
#  'shesepuede': 1,
#  'votaybotaatrump': 1,
#  'bidendidntwritethis': 1,
#  'gotrump': 5,
#  'teamtrump2020': 1,
#  'truth': 14,
#  'votehimout': 123,
#  'bidenharris': 65,
#  'dumptrump': 22,
#  'voteblue': 22,
#  'últimahora': 24,
#  'afp': 17,
#  'fuckem2020': 1,
#  'stopthesteal': 7,
#  '29sept': 1,
#  '2020presidentialdebate': 6,
#  'regainingthestandard': 1,
#  'debatechallenge2020': 1,
#  'fitness': 1,
#  'health': 4,
#  'smashteam': 1,
#  'centrfit': 1,
#  'biden2020': 53,
#  'covid_19': 10,
#  'coronatraining': 1,
#  'pridefamily': 7,
#  'pridenews1': 4,
#  'debatedrinkinggame': 2,
#  'breakingnews': 16,
#  'debates202': 4,
#  'debatequotesfromthefuture': 1,
#  'gop': 36,
#  'leadright': 5,
#  'trump2020victory': 3,
#  'greatsuccess': 1,
#  'fakenewsmedia': 25,
#  'creepyjoebiden': 6,
#  'trumpliedpeopledied': 16,
#  'penceknew': 1,
#  'gopcomplicittraitors': 10,
#  'foxknew': 1,
#  'cdcknew': 1,
#  'fdaknew': 1,
#  'taxfraudtrump': 4,
#  'penceisamurderer': 1,
#  'backtobluepa': 2,
#  'bitcoin': 9,
#  'justsayin': 2,
#  'trumpisaloser': 34,
#  'trumptaxcheat': 6,
#  'trumpisnot': 1,
#  '2020nojoke': 4,
#  'bidenharris20': 1,
#  'joepay': 1,
#  'elpaís': 1,
#  'chriswallace': 143,
#  'performanceenhancer': 1,
#  'trumpisafraud': 7,
#  'cashforballots': 13,
#  'trumpfamilytaxfraud': 1,
#  'ufc': 1,
#  'trumpliesmatter': 2,
#  'de': 16,
#  'mueller': 8,
#  'speakerpelosi': 1,
#  'cults': 1,
#  'psychiatry': 1,
#  'psychopaths': 1,
#  'malignantnarcissist': 2,
#  'mentalhealth': 1,
#  'experts': 1,
#  'silenced': 1,
#  'trumpsmentalunhealth': 1,
#  'removetrumpnow': 1,
#  'rsbn': 1,
#  'cripthevote': 2,
#  'stopfakenewspolls': 1,
#  'foxfakenews': 2,
#  'stopfoxfakenews': 1,
#  'amyconeybarrett': 12,
#  'tuesdaydebate': 2,
#  'orangeidiot': 2,
#  'haha': 1,
#  'bingo': 1,
#  'trumptaxes': 12,
#  'election2020': 96,
#  'الكويت': 1,
#  'صباح_الأحمد_الجابر_': 1,
#  'healthcare': 4,
#  'factcheckthis': 2,
#  'advertising': 1,
#  'marketing': 2,
#  'socialmedia': 2,
#  'influencermarketing': 1,
#  'gojoe': 4,
#  'studentstweetpolitics': 1,
#  'uspresidentialdebate': 7,
#  'brilliant': 1,
#  'turnip2020': 1,
#  'bidoon2002': 1,
#  'ilovemynation': 1,
#  'debatenight': 29,
#  'debates2': 6,
#  'bs': 1,
#  'nomoreyears': 1,
#  'deb': 17,
#  'keepyappin': 1,
#  'argentinasuppor': 1,
#  'd': 7,
#  'chinesewuhanvirus': 1,
#  'demonrats': 2,
#  'basementbiden': 1,
#  'quidproquojoe': 3,
#  'hunterchina': 1,
#  'moscowhunter': 3,
#  'voteredtosaveamerica2020': 23,
#  'votered2020removeeverydemocrat': 5,
#  'trump2020nowmorethanever': 26,
#  'shutupman': 47,
#  'sulsvote4pres': 1,
#  'retweeet': 1,
#  'retweeetplease': 1,
#  'prescriptiondrugs': 1,
#  'pedodon': 1,
#  'willyoushutupman': 15,
#  'tds': 2,
#  'shutuptrump': 2,
#  'didtrump': 1,
#  'trumpisanidiot': 2,
#  'uneducatedtrump': 1,
#  'trumpisaliar': 14,
#  'vv': 1,
#  'teamjoe': 5,
#  'scrantonvsparkave': 1,
#  'presidenttrump': 60,
#  'votebluetosaveamerica': 34,
#  'presidementia': 11,
#  'byedon2020': 4,
#  'stfudonald': 1,
#  'iykyk': 1,
#  'hidinbiden': 4,
#  'burnaboy': 1,
#  'snapchat': 1,
#  'wizkid': 1,
#  'smilechallenge': 1,
#  'votejoe': 3,
#  'idiottrump': 1,
#  'deba': 12,
#  'voteforscience': 1,
#  'berniemanifesto': 1,
#  'elecci': 1,
#  'hamsa': 2,
#  'jewishgifts': 1,
#  'ejwtt': 1,
#  'rwchst': 1,
#  'latinogreeksforbidenharris': 1,
#  'allinforohio': 1,
#  'aftvotes': 1,
#  'nytimes': 4,
#  'election': 18,
#  'debateover': 7,
#  'freshtweets': 1,
#  'debates20': 12,
#  'clown': 17,
#  'trumpisunwell': 11,
#  'presidentialde': 14,
#  'joebiden2020': 5,
#  'rip': 1,
#  'ovdb': 1,
#  'demcast': 7,
#  'bethechange4usa': 1,
#  'onev1': 6,
#  'mlbplayoffs': 1,
#  'bronxbombers': 1,
#  'beijingbiden': 6,
#  'justice': 2,
#  'exonerateflynn': 1,
#  'defundthepolice': 2,
#  'wallace': 6,
#  'hatethemboth': 1,
#  'ag': 2,
#  'mcvotes2020': 1,
#  'leftunity': 1,
#  'thisisamerica': 1,
#  'live': 5,
#  'fuckthenarrative': 1,
#  'frump': 1,
#  'fakenews': 32,
#  'auntietweetsthedebates': 1,
#  'trumplied200kdied': 6,
#  'presidentialdebate2': 2,
#  'thatisall': 1,
#  'mrpresident': 3,
#  'ncugopo': 1,
#  'hunterbiden': 19,
#  'swamp': 1,
#  'b': 5,
#  'bidenwonthedebate': 197,
#  'trumplandslide2020': 10,
#  'thisclown': 1,
#  'presidentialdebates2020': 20,
#  '2020debates': 2,
#  'chriswallacefail': 1,
#  'factcheck': 9,
#  'budenwonthedebate': 1,
#  'dumptrump2020': 20,
#  'blacklivesmatter': 84,
#  'iapolitics': 1,
#  'votebidenharristoendthisnightmare': 10,
#  'presidentialdeb': 1,
#  'trumpisaracist': 127,
#  'votebidenharris2020': 41,
#  'stupidbastard': 1,
#  'rememberinnovember': 9,
#  'debatecnn': 2,
#  'nationalcoffeeday': 1,
#  'trumpbiden2020': 1,
#  'pakistan': 2,
#  'usa': 55,
#  'voteearly': 32,
#  'healthequity': 1,
#  'trumpvsbiden2020': 3,
#  'bidencalm': 4,
#  'antifa': 37,
#  'bidrn': 1,
#  'voteblue2020': 22,
#  'factsmatter': 7,
#  'riggedelection': 4,
#  'electionfraud': 3,
#  'democratballotharvestin': 1,
#  'cringe': 1,
#  'unitedshades': 1,
#  'vinnie2020': 1,
#  'eagles': 2,
#  'crowderdeba': 1,
#  'scandalfreeadministration': 1,
#  'catsoutofthebag': 1,
#  'lockobamaup': 1,
#  'votetrump20': 1,
#  'worstpresidentinhistory': 6,
#  'votetrumpout': 18,
#  'mypresident': 2,
#  'presidentialelection2020': 1,
#  'bidenwondebates': 1,
#  'freeloaderinchief': 1,
#  'bullyinchief': 2,
#  'russianbountiesonourtroops': 6,
#  'nomoredebates': 6,
#  'abusive': 1,
#  'factchecking': 3,
#  'trumpfailed': 2,
#  'crazypres': 1,
#  'bidenwon': 12,
#  'chriswallaceworstmoderator': 1,
#  'firechriswallace': 14,
#  'staceyabrams': 1,
#  '45': 10,
#  'presi': 19,
#  'votethisclownout': 1,
#  'proudboysstandingby': 1,
#  'willyoushutup': 2,
#  'notkarensstickers': 2,
#  'prayerwarriors': 1,
#  'crystalenthusiasts': 1,
#  'positivevibethrowers': 1,
#  'votebidenharrist': 1,
#  'bidenpedofilo': 1,
#  'nothingcanstopwhatiscoming': 3,
#  'cia': 3,
#  'fbi': 4,
#  'hillary': 4,
#  'obama': 26,
#  'americ': 1,
#  'trump2020landslidevictory': 28,
#  'joebi': 13,
#  'hanity': 1,
#  'foxnews': 51,
#  'postcardstovoters': 1,
#  'potus': 51,
#  'faucithefraud': 1,
#  'greatamericancomeback': 1,
#  'lockfauciup': 1,
#  'faucigenocide': 1,
#  'whitesupremacyisajoke': 1,
#  'cdnpoli': 6,
#  'abpoli': 1,
#  'uspoli': 4,
#  'trumptrainwreck': 5,
#  'bullytrump': 1,
#  'govote': 1,
#  'whowillbeawitness': 1,
#  'epicfail': 1,
#  'shitshow': 5,
#  'favorite': 1,
#  'trumpcult': 1,
#  'trumpertantrum': 1,
#  'trumpnotthemanwiththeplan': 1,
#  'boguspotus': 1,
#  'dribblindon': 1,
#  'tremblintrump': 1,
#  'bidenforthewin': 1,
#  'bidenforallamerica': 1,
#  'whitesupremacist': 13,
#  'vpdebate': 1,
#  'dsdems': 1,
#  'trumpknew': 13,
#  'trumpunhinged': 1,
#  'trumpchaos': 8,
#  'harris': 3,
#  'liberalismisamentaldisorder': 8,
#  'socialismkills': 3,
#  'voterfraudisreal': 5,
#  'gavinnewsom': 1,
#  '1619project': 1,
#  'morevoicesbetterchoices': 2,
#  'makeamericagreatagain': 22,
#  'muchlove': 1,
#  'trumplied200kamericansdied': 5,
#  'russiahoax': 6,
#  'electionday': 3,
#  'elections': 7,
#  'poll': 7,
#  'polls': 2,
#  'realdonaldtrump': 7,
#  'trumpwaspathetic': 1,
#  'unidadpatriotaanteelbloqueo': 1,
#  'unhinged': 2,
#  'unfit': 2,
#  'trumpisatraitor': 19,
#  'goodtoknow': 13,
#  'tx06': 2,
#  'txpolitics': 1,
#  'fallonmon': 2,
#  'sadgovteacher': 1,
#  'joedormilon': 1,
#  'greennewdeal': 27,
#  'putinspuppy': 6,
#  'journalismisdead': 2,
#  'bidenisdone': 1,
#  'chrisw': 1,
#  'antitrumpadvocate': 1,
#  'unpresidential': 1,
#  'stfutrump': 2,
#  'firewray': 2,
#  'firewraynow': 3,
#  '8216': 1,
#  '8217': 3,
#  'joewonthedebate': 3,
#  'pennsylvaniavoters': 1,
#  'brokeasstrump': 2,
#  'debat': 7,
#  'trumpislosing': 14,
#  'uspol': 2,
#  'uspolitics': 3,
#  'bi': 3,
#  'retrofpuc': 1,
#  'hazardpay': 1,
#  'airlinebail': 1,
#  'cpc': 2,
#  'resista': 1,
#  'bbcrealitycheck': 1,
#  'enjoytheshow': 1,
#  'metoo': 6,
#  'dueprocess': 1,
#  'joepayshistaxes': 3,
#  'trumpdestroysdemocracy': 3,
#  'romneygardnerladygallspinelessliars': 3,
#  'trumpmurdered200kamericans': 1,
#  'thegopisdead': 3,
#  'presidentbiden': 3,
#  'vicepresidentharris': 2,
#  'votebiden': 6,
#  'fdt': 1,
#  'danbongino': 5,
#  'stablegenius': 6,
#  'riggeddebate': 2,
#  'trumpversesbidenwallaceandthemedia': 1,
#  'chriswallace2020': 1,
#  'hidenbiden': 9,
#  'hace4años': 5,
#  'shitshowdonnie': 1,
#  'pedojoebiden': 3,
#  'obamabidengate': 4,
#  'wakeuppeople': 2,
#  'gitmo': 4,
#  'bidentherapist': 4,
#  'heelsupharris': 2,
#  'ther': 3,
#  'hammeredintenminutes': 1,
#  'america': 18,
#  'democrats': 42,
#  'trumpbidendebate': 10,
#  'trumpisalaughingstock': 22,
#  'obamagate': 17,
#  'trumpliesamericansdie': 11,
#  'latinos': 7,
#  'bobwoodward': 1,
#  'spygate': 14,
#  'maddow': 3,
#  'maddowmoderator': 1,
#  'dontbanterrencekwilliams': 1,
#  'maketuckerapresidentialdebatemoderator': 1,
#  'debatebingo': 1,
#  '750dollardon': 1,
#  'blm': 41,
#  'democracyforall': 1,
#  'antifaterrorists': 6,
#  'votetrump2020tos': 1,
#  'idenouncewhitesupremists': 1,
#  'president': 4,
#  'comeyrule': 2,
#  'ตอบเฉพาะคนเม': 1,
#  'เซฟโซนของต': 1,
#  'thegentlemenlive': 1,
#  'imethค': 1,
#  'crookedjoebiden': 2,
#  'bidencrimefamily': 7,
#  'bidenriots': 9,
#  'chiefsniffer': 1,
#  'bidenisracist': 1,
#  'quidprojoe': 3,
#  'lyingdogfacedponysoldier': 1,
#  'plagerist': 1,
#  'owned': 1,
#  'kag': 55,
#  'platinumplan': 9,
#  'c': 24,
#  'debatabletakes': 19,
#  'notmypresident': 9,
#  'magats': 3,
#  'aditya': 1,
#  'आत': 3,
#  'justiceformanishavalmiki': 2,
#  'whereissmritiirani': 1,
#  'shameonyogi': 1,
#  'hathras': 1,
#  'justiceformanisha': 1,
#  'yogiadityanath': 1,
#  'hathrashorror': 1,
#  'justiceforhathrasvictim': 1,
#  'wednesdaymorning': 3,
#  'manishavalmiki': 1,
#  'ह': 1,
#  'poutine': 1,
#  'donaldtrum': 4,
#  'jobsreport': 5,
#  'mts': 1,
#  'free': 2,
#  'rides': 1,
#  'november3rd': 3,
#  'pollingplaces': 1,
#  'leftistsalwaysproject': 1,
#  'auspol': 5,
#  'msm': 16,
#  'ccpchina': 3,
#  'chinajoe': 6,
#  'qanon': 14,
#  'wwg1wga': 14,
#  'thegreatawakening': 7,
#  'digitalsoldiers': 3,
#  'frazzledrip': 1,
#  'redpill': 5,
#  'freedom': 1,
#  'q': 2,
#  'trumptrain': 10,
#  'qarmy': 1,
#  'worldwide': 1,
#  'republican': 21,
#  'democrat': 10,
#  '2': 9,
#  'bodylanguage': 3,
#  'fakeheadlinebot': 3,
#  'learntocode': 3,
#  'makeatwitterbot': 3,
#  'javascript': 2,
#  'parody': 1,
#  'daddyissues': 1,
#  'votehimout2020': 20,
#  'bidenwondebate': 6,
#  '29sep': 3,
#  'backtheblue': 9,
#  'fuck2020': 1,
#  'fuckwhitesupremacists': 1,
#  'hathrashorrorshocksindia': 1,
#  'btsonfallon_d2': 2,
#  'johncena': 2,
#  'hathrascase': 1,
#  'news': 17,
#  'trekthevote': 1,
#  'trektuesday': 1,
#  'joefornursinghome2020': 1,
#  'presidentialdeba': 3,
#  '新中国联邦': 1,
#  'china': 23,
#  'tarareade': 1,
#  'world': 3,
#  'mastersofprojection': 1,
#  'presidential': 6,
#  'berniesanders': 1,
#  'racistinchief': 11,
#  'gopcorruptionovercountry': 13,
#  'trumpisanationalsecuritythreat': 6,
#  'wecaughtthemall': 1,
#  'byeeric': 2,
#  'covid': 52,
#  'pennsylvania': 10,
#  'wisconsin': 11,
#  'ohio': 11,
#  'trumphateswhitepeople': 1,
#  'standdownandstandby': 6,
#  's386': 3,
#  'standwithscott': 1,
#  's386blockedflprotected': 1,
#  'nos386noharassment': 1,
#  'texas': 13,
#  'traitortrump': 18,
#  'confederatetrump': 1,
#  'nazitrump': 1,
#  'ezgimola': 1,
#  'maga20': 1,
#  'colombiac': 1,
#  'trumpisala': 1,
#  'checkpoint': 1,
#  'dlozlami': 1,
#  'teamh': 6,
#  'tshirtdesign': 1,
#  'tshirt': 2,
#  'graphicdesigner': 1,
#  'graphicdesign': 2,
#  'proudboys': 62,
#  'whitesupremacy': 26,
#  'helenreddy': 1,
#  'danabash': 2,
#  'presidentofthe': 1,
#  'blmantifaterroriststhugs': 3,
#  'truthmatters': 6,
#  'tr': 10,
#  'earpiece': 2,
#  'earpiecegate': 1,
#  'saveourchildren': 4,
#  'wieszwiecej': 1,
#  'granvictoria': 1,
#  'lawandorder': 7,
#  'presid': 2,
#  'presidentialdebat': 1,
#  'takeaways': 1,
#  'voteforamerica': 3,
#  'vote2020': 5,
#  'projection': 2,
#  'trumpisnotwell': 7,
#  'trumpvirusdeathtoll200k': 2,
#  'imvotingforbiden': 1,
#  'trumphatesourveterans': 1,
#  'election2020https': 1,
#  'wednesdaywisdom': 9,
#  'wednesdaythoughts': 5,
#  'totche': 2,
#  'spainsupportstrump': 2,
#  'gmb': 2,
#  'decision2020': 4,
#  'joebideniscorrupt': 2,
#  'notusthem': 1,
#  'covid19india': 2,
#  'listeningdevice': 1,
#  'cheat': 3,
#  'trump2020landsli': 1,
#  'trumpcrimefamilymustgo': 1,
#  'agbarrmustresignnow': 1,
#  'republicansaredestroyingamerica': 4,
#  'editorial': 2,
#  'donthecon': 10,
#  'greenne': 1,
#  'optoribogenetics': 1,
#  'rickbeijingscott': 1,
#  'interrupting': 2,
#  'rage': 1,
#  'americans': 11,
#  'rbg': 7,
#  'johnlewis': 1,
#  'qanons': 11,
#  'congress': 4,
#  'trumphatesourmilitary': 2,
#  'climatearsonist': 1,
#  'fakeoutrage': 2,
#  'foolishness': 1,
#  'painfultowatch': 1,
#  'ترامپ': 1,
#  'hongkong': 4,
#  'debatehk': 4,
#  'liar': 6,
#  'orangedicktaterwanna': 1,
#  'whitesupremacists': 19,
#  'débat': 4,
#  'jrobgov': 1,
#  'lyingclown': 1,
#  'trumpisabusive': 3,
#  'trumpisanabuser': 3,
#  'wiregate': 1,
#  'vota': 1,
#  'fakemedia': 2,
#  'makeyourvote': 1,
#  'r2p': 3,
#  'dailyexpress': 1,
#  'queen': 2,
#  'england': 3,
#  'ue': 3,
#  'uk': 6,
#  'macron': 5,
#  'people': 3,
#  'tabloid': 2,
#  'coronavirus': 121,
#  'sunak': 2,
#  'borisjohnson': 4,
#  'princewilliam': 2,
#  'middleton': 1,
#  'epstein': 3,
#  'princeandrew': 2,
#  'maxwell': 2,
#  'princeharry': 2,
#  'kanyewest': 1,
#  'pm': 2,
#  'simoncowell': 1,
#  'dianarigg': 2,
#  'trumpriots': 2,
#  'trumpcrimefamilyforprison': 6,
#  'deepstatecabal': 1,
#  'illegitimatepresident': 1,
#  'howdymodi': 1,
#  'zemmour': 2,
#  'fuckingbitch': 1,
#  'stopfascismnow': 1,
#  'votetrump2020tosaveameric': 1,
#  'demcastmi': 1,
#  'earpiecebiden': 1,
#  'democratstheenemywithin': 13,
#  'sleepyslowjoe': 2,
#  'crazybernie': 2,
#  'trumpkilledmymother': 1,
#  'ditchmitch': 2,
#  'moscowmitch': 6,
#  'byelindsey': 2,
#  'trumppenceoutnow': 1,
#  'trumpisacuntpassiton': 1,
#  'joewired': 36,
#  'voteready': 7,
#  'charliehebdo': 1,
#  'teachbánaithe': 1,
#  'abolishtheelectoralcollege': 1,
#  'americasgreatestmistake': 7,
#  'cpd': 1,
#  'debatepresidencial': 2,
#  'casewesternreserveuniversity': 1,
#  'ppaca': 1,
#  'obamacare': 2,
#  'barackobama': 3,
#  'ruthbaderginsburg': 2,
#  'noticias': 5,
#  'godiswatching': 1,
#  'proudboysstandby': 6,
#  'khaligraph': 2,
#  'ruto': 2,
#  'tinakaggia': 3,
#  'kibera': 2,
#  'mombasaroad': 2,
#  'feminism': 2,
#  'trumpbidendebate2020': 1,
#  'topic': 1,
#  'trumpwondebate': 5,
#  'chriswallaceisajoke': 9,
#  'racisttrump': 15,
#  'schoolsreop': 4,
#  'putinspuppet': 9,
#  'hoax': 18,
#  'goodjob': 1,
#  'logo': 3,
#  'businesscard': 1,
#  'branding': 1,
#  'web': 1,
#  'instagram': 1,
#  'facebook': 7,
#  'twitter': 3,
#  'banners': 1,
#  'business': 2,
#  'company': 1,
#  'realestate': 1,
#  'fashion': 2,
#  'food': 1,
#  'uselection2020': 3,
#  'democraticsocialist': 1,
#  'ترامب': 9,
#  'notfallingforthatnonsense': 1,
#  'maga2020landslidevictory': 6,
#  'keepamer': 1,
#  'voteforbidenharris': 1,
#  'usa2020': 3,
#  'rassegnastampa': 1,
#  'maizebaronofsugoi': 1,
#  'schoolsreopening': 1,
#  'mwashumbenashugaboy': 1,
#  'medicareforall': 4,
#  'joemo': 1,
#  'criminalgang': 1,
#  'xijinping': 1,
#  'rt': 5,
#  'foxandfriends': 8,
#  'freerealitywinner': 2,
#  'trumpmeltdownlive': 1,
#  'godhelpus': 1,
#  'americapraynow': 1,
#  'weareblessedshelost': 1,
#  'democrates': 2,
#  'bigyikes': 1,
#  'leadersdebate': 1,
#  'badthingshappeninphiladelphia': 1,
#  'defendourdemocracy': 1,
#  'saveusps': 1,
#  'savetheunitedstatespostalservice': 1,
#  'savetheusps': 1,
#  'pony': 1,
#  'unitedstatespostalservice': 1,
#  'uses': 1,
#  'brianschatz': 1,
#  'tulsigabbard': 1,
#  'maziehirono': 1,
#  'usmail': 1,
#  'us': 11,
#  'economy': 2,
#  'trumpisunfit': 3,
#  'cnn': 28,
#  'bidenruledtrump': 1,
#  'portland': 3,
#  'savethechildren': 15,
#  'pknt': 1,
#  'inperson': 2,
#  'showupfordemocracy': 2,
#  'votejoebiden2020': 3,
#  'trumppedoyears': 1,
#  'demsarede': 1,
#  'russianoligarch': 1,
#  'raceforthe': 1,
#  'latinosfortrump': 10,
#  'bidenlies': 5,
#  'trumpbidenrtve': 1,
#  'ukraine': 7,
#  'trending': 4,
#  'trendingnews': 2,
#  'trump2020tosaveamerica': 22,
#  'zeroilfolle': 1,
#  'skybaseball': 1,
#  'antifaisjustanidea': 3,
#  's': 3,
#  'nazigermany': 1,
#  'trumpspupils': 3,
#  'weknowjoe': 1,
#  'biasedwallace': 1,
#  'biased': 2,
#  'investigation': 1,
#  'americafirst': 16,
#  'getwoke': 1,
#  'truthbetold': 1,
#  'truthoverlies': 1,
#  'blacks': 1,
#  'btsweek': 5,
#  'blackpink': 6,
#  'trumpproudboys': 2,
#  'bbtvi': 1,
#  'jamaica': 1,
#  'nigeria': 5,
#  'nyc': 2,
#  'newyork': 3,
#  'miami': 3,
#  'atlanta': 5,
#  'sanfrancisco': 1,
#  'defundpolice': 1,
#  'lawenforcement': 1,
#  'pizza': 1,
#  'pineapple': 1,
#  'pineappleonpizza': 1,
#  'meme': 1,
#  'funnymeme': 1,
#  'lol': 1,
#  'faktenfinder': 1,
#  'uswahl2020': 2,
#  'faktencheck': 1,
#  'c4news': 3,
#  'g30spki': 1,
#  'hukumberat': 1,
#  'curistart': 1,
#  'mass': 1,
#  'eskopifrappe': 1,
#  'suho': 1,
#  'herragolftwittler': 1,
#  'racismmustfall': 1,
#  'punktrump': 1,
#  'trumpracist': 6,
#  'terzake': 1,
#  'sacramento': 1,
#  'lügenpresse': 1,
#  'jakpost': 1,
#  'votebidenharristosaveamerica': 18,
#  'liestream': 1,
#  'bindenwon': 1,
#  'presendentialdebate2020': 1,
#  'murdoch': 1,
#  'racism': 7,
#  'socialismo': 1,
#  'بايدن': 1,
#  'شاهد_سكاي': 1,
#  'ccp': 9,
#  'บ': 1,
#  'bidenliesagain': 2,
#  'drugaddiction': 1,
#  'drugwarrior': 1,
#  'vp': 1,
#  'uselections': 3,
#  'shitshowpresident': 1,
#  'duel': 1,
#  'démocrate': 1,
#  'standbackstandby': 1,
#  'kag2020': 17,
#  'unfittobepr': 3,
#  'stayathome': 1,
#  'healthyathome': 1,
#  'nantes': 1,
#  'nice': 1,
#  'lille': 1,
#  'paris': 1,
#  'toulouse': 1,
#  'lyon': 2,
#  'marseille': 1,
#  'terrassa': 1,
#  'barcelona': 1,
#  'madrid': 1,
#  'zaragoza': 1,
#  'seville': 1,
#  'valencia': 1,
#  'stuttgart': 1,
#  'koln': 1,
#  'hannover': 1,
#  'munchen': 1,
#  'hamburg': 1,
#  ...}

# %%
full_text_hastags_dict_sorted = sorted(full_text_hastags_dict.items()
                                       , key=lambda kv: kv[1]
                                       , reverse=True
                                      )
full_text_hastags_dict_sorted
# Out:
# [('debates2020', 2085),
#  ('trump', 675),
#  ('covid19', 511),
#  ('trump2020', 493),
#  ('trumphascovid', 470),
#  ('maga', 428),
#  ('vote', 350),
#  ('presidentialdebate', 307),
#  ('biden', 281),
#  ('debates', 266),
#  ('joebiden', 200),
#  ('bidenwonthedebate', 197),
#  ('bidenharris2020', 183),
#  ('debate2020', 181),
#  ('presidentialdebate2020', 173),
#  ('trumpmeltdown', 163),
#  ('debate', 156),
#  ('donaldtrump', 150),
#  ('chriswallace', 143),
#  ('trumpisaracist', 127),
#  ('votehimout', 123),
#  ('coronavirus', 121),
#  ('election2020', 96),
#  ('proudboytrump', 92),
#  ('worsttrumpever', 89),
#  ('blacklivesmatter', 84),
#  ('bountygate', 81),
#  ('trumpvirus', 77),
#  ('trumpcovid', 74),
#  ('breaking', 68),
#  ('maga2020', 66),
#  ('bidenharris', 65),
#  ('proudboys', 62),
#  ('melaniatapes', 61),
#  ('presidenttrump', 60),
#  ('endtrumpshate', 58),
#  ('usa', 55),
#  ('kag', 55),
#  ('biden2020', 53),
#  ('covid', 52),
#  ('foxnews', 51),
#  ('potus', 51),
#  ('kkk', 51),
#  ('shutupman', 47),
#  ('trump2020landslide', 44),
#  ('smartnews', 42),
#  ('democrats', 42),
#  ('votebidenharris2020', 41),
#  ('blm', 41),
#  ('1', 39),
#  ('followthemoney', 38),
#  ('antifa', 37),
#  ('andrewcuomo', 37),
#  ('debatetuesday', 36),
#  ('gop', 36),
#  ('joewired', 36),
#  ('voterfraud', 36),
#  ('wearamask', 36),
#  ('trumpisaloser', 34),
#  ('votebluetosaveamerica', 34),
#  ('votebluetoendthisnightmare', 33),
#  ('elections2020', 33),
#  ('fakenews', 32),
#  ('voteearly', 32),
#  ('votersuppression', 32),
#  ('2020debate', 30),
#  ('debatenight', 29),
#  ('keepamericagreat', 28),
#  ('eeuu', 28),
#  ('trump2020landslidevictory', 28),
#  ('cnn', 28),
#  ('greennewdeal', 27),
#  ('sleepyjoe', 26),
#  ('argentinasupportstrump', 26),
#  ('trumpcrimefamily', 26),
#  ('bidenharristosaveamerica', 26),
#  ('trump2020nowmorethanever', 26),
#  ('obama', 26),
#  ('whitesupremacy', 26),
#  ('trumptaxreturns', 25),
#  ('fakenewsmedia', 25),
#  ('itiswhatitis', 25),
#  ('trumpisanationaldisgrace', 24),
#  ('últimahora', 24),
#  ('c', 24),
#  ('melaniatrump', 24),
#  ('new', 23),
#  ('voteredtosaveamerica2020', 23),
#  ('china', 23),
#  ('melania', 23),
#  ('prayfortrump', 23),
#  ('snlpremiere', 23),
#  ('hopehicks', 23),
#  ('walkaway', 22),
#  ('dumptrump', 22),
#  ('voteblue', 22),
#  ('voteblue2020', 22),
#  ('makeamericagreatagain', 22),
#  ('trumpisalaughingstock', 22),
#  ('trump2020tosaveamerica', 22),
#  ('minnesota', 22),
#  ('votered', 22),
#  ('racist', 22),
#  ('karma', 22),
#  ('trumppence2020', 21),
#  ('bidenharrislandslide2020', 21),
#  ('americaortrump', 21),
#  ('republican', 21),
#  ('wakeupamerica', 20),
#  ('presidentialdebates2020', 20),
#  ('dumptrump2020', 20),
#  ('votehimout2020', 20),
#  ('armyfortrump', 19),
#  ('oann', 19),
#  ('hunterbiden', 19),
#  ('presi', 19),
#  ('trumpisatraitor', 19),
#  ('debatabletakes', 19),
#  ('whitesupremacists', 19),
#  ('4moreyears', 19),
#  ('lindseyforbiden', 19),
#  ('turntexasblue', 18),
#  ('bidenharris2020tosaveamerica', 18),
#  ('election', 18),
#  ('votetrumpout', 18),
#  ('america', 18),
#  ('traitortrump', 18),
#  ('hoax', 18),
#  ('votebidenharristosaveamerica', 18),
#  ('bideniswinning', 18),
#  ('afp', 17),
#  ('deb', 17),
#  ('clown', 17),
#  ('obamagate', 17),
#  ('news', 17),
#  ('kag2020', 17),
#  ('voteredtosaveamerica', 17),
#  ('votetrump2020tosaveamerica', 17),
#  ('bebest', 17),
#  ('covidcaughttrump', 17),
#  ('ballotharvesting', 16),
#  ('scotus', 16),
#  ('breakingnews', 16),
#  ('trumpliedpeopledied', 16),
#  ('de', 16),
#  ('msm', 16),
#  ('americafirst', 16),
#  ('winning', 16),
#  ('kylerittenhouse', 16),
#  ('votelibertarian', 16),
#  ('whereistheriver', 16),
#  ('liarinchief', 15),
#  ('gymjordan', 15),
#  ('willyoushutupman', 15),
#  ('racisttrump', 15),
#  ('savethechildren', 15),
#  ('covidー19', 15),
#  ('northcarolina', 15),
#  ('trumprally', 15),
#  ('msnbc', 14),
#  ('truth', 14),
#  ('trumpisaliar', 14),
#  ('presidentialde', 14),
#  ('firechriswallace', 14),
#  ('trumpislosing', 14),
#  ('spygate', 14),
#  ('qanon', 14),
#  ('wwg1wga', 14),
#  ('republicansforbiden', 14),
#  ('themoreyouknow', 14),
#  ('durham', 14),
#  ('wearadamnmask', 14),
#  ('byerudy', 13),
#  ('politics', 13),
#  ('cashforballots', 13),
#  ('joebi', 13),
#  ('whitesupremacist', 13),
#  ('trumpknew', 13),
#  ('goodtoknow', 13),
#  ('gopcorruptionovercountry', 13),
#  ('texas', 13),
#  ('democratstheenemywithin', 13),
#  ('morningjoe', 13),
#  ('resist', 13),
#  ('2020election', 13),
#  ('t', 13),
#  ('corona', 13),
#  ('bidensfocusedonus', 13),
#  ('fucktrump', 12),
#  ('fightback', 12),
#  ('amyconeybarrett', 12),
#  ('trumptaxes', 12),
#  ('deba', 12),
#  ('debates20', 12),
#  ('bidenwon', 12),
#  ('walkawayfromdemocrats', 12),
#  ('purplepower', 12),
#  ('godwins', 12),
#  ('blackvoicesfortrump', 12),
#  ('voteinperson', 12),
#  ('mcu', 12),
#  ('trumpthesnake', 12),
#  ('m', 12),
#  ('whitmerdeathtoll', 12),
#  ('trumpisbroke', 11),
#  ('republicans', 11),
#  ('p', 11),
#  ('florida', 11),
#  ('presidementia', 11),
#  ('trumpisunwell', 11),
#  ('trumpliesamericansdie', 11),
#  ('racistinchief', 11),
#  ('wisconsin', 11),
#  ('ohio', 11),
#  ('americans', 11),
#  ('qanons', 11),
#  ('us', 11),
#  ('draintheswamp', 11),
#  ('wallacefail', 11),
#  ('bidenharris2020landslide', 11),
#  ('youandmeboth', 11),
#  ('trumpliedamericansdied', 11),
#  ('restartmiga', 11),
#  ('heroesact', 11),
#  ('trumphascorona', 11),
#  ('corruption', 10),
#  ('kamalaharris', 10),
#  ('covid_19', 10),
#  ('gopcomplicittraitors', 10),
#  ('trumplandslide2020', 10),
#  ('votebidenharristoendthisnightmare', 10),
#  ('45', 10),
#  ('trumpbidendebate', 10),
#  ('trumptrain', 10),
#  ('democrat', 10),
#  ('pennsylvania', 10),
#  ('tr', 10),
#  ('donthecon', 10),
#  ('latinosfortrump', 10),
#  ('democratsaredestroyingamerica', 10),
#  ('reliefnow', 10),
#  ('extendpsp', 10),
#  ('votebluedownballot', 10),
#  ('putinspiglet', 10),
#  ('saveour', 10),
#  ('huge', 10),
#  ('bidenisaliar', 10),
#  ('trumpbangeuroterrorists', 10),
#  ('checkjoesears', 9),
#  ('whereshunter', 9),
#  ('dnc', 9),
#  ('trumplies', 9),
#  ('bitcoin', 9),
#  ('factcheck', 9),
#  ('rememberinnovember', 9),
#  ('hidenbiden', 9),
#  ('bidenriots', 9),
#  ('platinumplan', 9),
#  ('notmypresident', 9),
#  ('2', 9),
#  ('backtheblue', 9),
#  ('wednesdaywisdom', 9),
#  ('chriswallaceisajoke', 9),
#  ('putinspuppet', 9),
#  ('ترامب', 9),
#  ('ccp', 9),
#  ('ccot', 9),
#  ('putin', 9),
#  ('nevertrump', 9),
#  ('chinavirus', 9),
#  ('fourmoreyears', 9),
#  ('whitehouse', 9),
#  ('lockhimup', 9),
#  ('american', 9),
#  ('bidenwired', 9),
#  ('lockupivanka', 9),
#  ('democratsarecorrupt', 9),
#  ('thefive', 9),
#  ('duluth', 9),
#  ('wethepeople', 9),
#  ('dementiajoe', 9),
#  ('restartleader', 9),
#  ('nbafinals', 9),
#  ('benghazi', 9),
#  ('gymjordanknew', 8),
#  ('mueller', 8),
#  ('trumpchaos', 8),
#  ('liberalismisamentaldisorder', 8),
#  ('foxandfriends', 8),
#  ('miga', 8),
#  ('telemundo', 8),
#  ('iowa', 8),
#  ('pr', 8),
#  ('2020trumplandslide', 8),
#  ('1stdebate', 8),
#  ('russia', 8),
#  ('bluewave2020', 8),
#  ('ettd', 8),
#  ('losertrump', 8),
#  ('democracy', 8),
#  ('lakeshow', 8),
#  ('ccpvirus', 8),
#  ('proud', 8),
#  ('hydroxychloroquine', 8),
#  ('2oct', 8),
#  ('truckers4trump', 7),
#  ('trum', 7),
#  ('cleveland', 7),
#  ('stopthesteal', 7),
#  ('pridefamily', 7),
#  ('trumpisafraud', 7),
#  ('uspresidentialdebate', 7),
#  ('d', 7),
#  ('debateover', 7),
#  ('demcast', 7),
#  ('factsmatter', 7),
#  ('elections', 7),
#  ('poll', 7),
#  ('realdonaldtrump', 7),
#  ('debat', 7),
#  ('latinos', 7),
#  ('bidencrimefamily', 7),
#  ('thegreatawakening', 7),
#  ('lawandorder', 7),
#  ('trumpisnotwell', 7),
#  ('rbg', 7),
#  ('voteready', 7),
#  ('americasgreatestmistake', 7),
#  ('facebook', 7),
#  ('ukraine', 7),
#  ('racism', 7),
#  ('michigan', 7),
#  ('iran', 7),
#  ('bide', 7),
#  ('azerbaijan', 7),
#  ('たつのこ', 7),
#  ('loser', 7),
#  ('lyingbiden', 7),
#  ('fakepresident', 7),
#  ('trumpisawhitesupremacist', 7),
#  ('bluewave', 7),
#  ('patriot', 7),
#  ('delaware', 7),
#  ('opiniaonoar', 7),
#  ('deepstate', 7),
#  ('trumpisarapist', 7),
#  ('comey', 7),
#  ('pandemic', 7),
#  ('putinspuppetgoneadderall', 7),
#  ('goptrumpstainwillneverleave', 7),
#  ('randomthoughts', 7),
#  ('gotv', 7),
#  ('obstructionofjustice', 7),
#  ('me', 7),
#  ('melaniahateschristmas', 7),
#  ('flotus', 7),
#  ('domesticvio', 7),
#  ('crookedhillary', 6),
#  ('elecciones2020', 6),
#  ('joebidenkamalaharris2020', 6),
#  ('empathy', 6),
#  ('2020presidentialdebate', 6),
#  ('creepyjoebiden', 6),
#  ('trumptaxcheat', 6),
#  ('debates2', 6),
#  ('onev1', 6),
#  ('beijingbiden', 6),
#  ('wallace', 6),
#  ('trumplied200kdied', 6),
#  ('worstpresidentinhistory', 6),
#  ('russianbountiesonourtroops', 6),
#  ('nomoredebates', 6),
#  ('cdnpoli', 6),
#  ('russiahoax', 6),
#  ('putinspuppy', 6),
#  ('metoo', 6),
#  ('votebiden', 6),
#  ('stablegenius', 6),
#  ('antifaterrorists', 6),
#  ('chinajoe', 6),
#  ('bidenwondebate', 6),
#  ('presidential', 6),
#  ('trumpisanationalsecuritythreat', 6),
#  ('standdownandstandby', 6),
#  ('teamh', 6),
#  ('truthmatters', 6),
#  ('liar', 6),
#  ('uk', 6),
#  ('trumpcrimefamilyforprison', 6),
#  ('moscowmitch', 6),
#  ('proudboysstandby', 6),
#  ('maga2020landslidevictory', 6),
#  ('blackpink', 6),
#  ('trumpracist', 6),
#  ('acb', 6),
#  ('blmisaterroristorganization', 6),
#  ('womenfortrump', 6),
#  ('votebymail', 6),
#  ('apfactcheck', 6),
#  ('sleepyjoebiden', 6),
#  ('bidencoalition', 6),
#  ('trumpcoupplot', 6),
#  ('3', 6),
#  ('trumplieseverytimehespeaks', 6),
#  ('proudboy', 6),
#  ('deadlinewh', 6),
#  ('floridafortrump', 6),
#  ('tru', 6),
#  ('erictrump', 6),
#  ('cuba', 6),
#  ('thereidout', 6),
#  ('hannity', 6),
#  ('gopbetrayedamerica', 6),
#  ('trumptaxfraud', 6),
#  ('imanvellani', 6),
#  ('covidiots', 6),
#  ('artsakh', 6),
#  ('icymi', 6),
#  ('trumplandslidevictory2020', 6),
#  ('tbt', 6),
#  ('fullmoon', 6),
#  ('walterreed', 6),
#  ('trumph', 6),
#  ('ท', 6),
#  ('4moreears', 6),
#  ('fridaymorning', 6),
#  ('ultimahora', 6),
#  ('fridayfeeling', 6),
#  ('fridayvibes', 6),
#  ('magastrong', 6),
#  ('kidvicious', 5),
#  ('whatunitesus', 5),
#  ('mundo', 5),
#  ('internacional', 5),
#  ('canada', 5),
#  ('envideo', 5),
#  ('vot', 5),
#  ('gotrump', 5),
#  ('leadright', 5),
#  ('votered2020removeeverydemocrat', 5),
#  ('teamjoe', 5),
#  ('joebiden2020', 5),
#  ('live', 5),
#  ('b', 5),
#  ('trumptrainwreck', 5),
#  ('shitshow', 5),
#  ('voterfraudisreal', 5),
#  ('trumplied200kamericansdied', 5),
#  ('danbongino', 5),
#  ('hace4años', 5),
#  ('jobsreport', 5),
#  ('auspol', 5),
#  ('redpill', 5),
#  ('vote2020', 5),
#  ('wednesdaythoughts', 5),
#  ('macron', 5),
#  ('noticias', 5),
#  ('trumpwondebate', 5),
#  ('rt', 5),
#  ('bidenlies', 5),
#  ('btsweek', 5),
#  ('nigeria', 5),
#  ('atlanta', 5),
#  ('fact', 5),
#  ('arizona', 5),
#  ('freecoco', 5),
#  ('みかじ絵', 5),
#  ('桐生ココ', 5),
#  ('桐生ココへのペナルティ撤回せよ', 5),
#  ('amongus', 5),
#  ('executiveorder', 5),
#  ('2020', 5),
#  ('lyinbiden', 5),
#  ('preexistingconditions', 5),
#  ('wiredjoe', 5),
#  ('cult45', 5),
#  ('turnnyred', 5),
#  ('worstpresidentever', 5),
#  ('lindseyfor', 5),
#  ('demvoice1', 5),
#  ('terrorist', 5),
#  ('crypto', 5),
#  ('assange', 5),
#  ('pence', 5),
#  ('bestpresidentever', 5),
#  ('msmarvel', 5),
#  ('fakenewsmediaclowns', 5),
#  ('covidiot', 5),
#  ('tedcruz', 5),
#  ('bestpresidentever45', 5),
#  ('trumplostthedebate', 5),
#  ('trumpis', 5),
#  ('1a', 5),
#  ('military', 5),
#  ('blexit', 5),
#  ('qanon2020', 5),
#  ('kyle', 5),
#  ('mnrally', 5),
#  ('christian', 5),
#  ('resign', 5),
#  ('trumpdementiasyndrome', 5),
#  ('truckersfortrump', 5),
#  ('republicanparty', 5),
#  ('robertbyrd', 5),
#  ('liberals', 5),
#  ('artsakhstrong', 5),
#  ('steunsimmons', 5),
#  ('socialists', 5),
#  ('october1st', 5),
#  ('thursdaythoughts', 5),
#  ('cdc', 5),
#  ('sondakika', 5),
#  ('creepyuncle', 5),
#  ('imvotingfor', 5),
#  ('trumppatriots', 5),
#  ('johnroberts', 5),
#  ('crossfirehurricane', 5),
#  ('quarantine', 5),
#  ('trumphascov', 5),
#  ('trumphascovid19', 5),
#  ('godblessamerica', 5),
#  ('weloveyoutrump', 5),
#  ('teamjustice', 5),
#  ('steady', 5),
#  ('95minutesintrumpsamerica', 5),
#  ('trumptrain2020', 4),
#  ('aag', 4),
#  ('aag2020', 4),
#  ('hawkins', 4),
#  ('jorgensen', 4),
#  ('yacpolls', 4),
#  ('nyt', 4),
#  ('stoptrumpselectiontheft', 4),
#  ('billbarr', 4),
#  ('aca', 4),
#  ('letherspeak', 4),
#  ('fakedebates', 4),
#  ('health', 4),
#  ('pridenews1', 4),
#  ('debates202', 4),
#  ('taxfraudtrump', 4),
#  ('2020nojoke', 4),
#  ('healthcare', 4),
#  ('gojoe', 4),
#  ('byedon2020', 4),
#  ('hidinbiden', 4),
#  ('nytimes', 4),
#  ('bidencalm', 4),
#  ('riggedelection', 4),
#  ('fbi', 4),
#  ('hillary', 4),
#  ('uspoli', 4),
#  ('obamabidengate', 4),
#  ('gitmo', 4),
#  ('bidentherapist', 4),
#  ('president', 4),
#  ('donaldtrum', 4),
#  ('saveourchildren', 4),
#  ('decision2020', 4),
#  ('republicansaredestroyingamerica', 4),
#  ('congress', 4),
#  ('hongkong', 4),
#  ('debatehk', 4),
#  ('débat', 4),
#  ('borisjohnson', 4),
#  ('schoolsreop', 4),
#  ('medicareforall', 4),
#  ('trending', 4),
#  ('f', 4),
#  ('eurusd', 4),
#  ('restart_opposition', 4),
#  ('beatthecheat', 4),
#  ('biafra', 4),
#  ('blacksfortrump', 4),
#  ('biafrans', 4),
#  ('trmp', 4),
#  ('trump2', 4),
#  ('lockherup', 4),
#  ('loveisnottourism', 4),
#  ('india', 4),
#  ('asacoco', 4),
#  ('たつのこより会長に愛を込めて', 4),
#  ('votelikeyourlifedependsonit', 4),
#  ('firstpresidentialdebate', 4),
#  ('joementia', 4),
#  ('chriswallacethehack', 4),
#  ('buildbackbetter', 4),
#  ('moderator', 4),
#  ('spittingimage', 4),
#  ('trumplost', 4),
#  ('whitesupremacistinchief', 4),
#  ('fakenewschriswallacesavedjoe', 4),
#  ('boycottchriswallace', 4),
#  ('aviation', 4),
#  ('nobelpeaceprize', 4),
#  ('europe', 4),
#  ('saveourdemocracy', 4),
#  ('flipthesenateblue', 4),
#  ('lies', 4),
#  ('donaldjtrump', 4),
#  ('standdownstandby', 4),
#  ('southcarolina', 4),
#  ('treason', 4),
#  ('mailinballots', 4),
#  ('bernie', 4),
#  ('traitor', 4),
#  ('fascism', 4),
#  ('trumpisnotabillionaire', 4),
#  ('scsen', 4),
#  ('facts', 4),
#  ('kiryucoco', 4),
#  ('turkey', 4),
#  ('voteinperson2020', 4),
#  ('badthingshappeninphilly', 4),
#  ('usdebate', 4),
#  ('jamescomey', 4),
#  ('u', 4),
#  ('pu', 4),
#  ('r', 4),
#  ('superspreader', 4),
#  ('wiredbiden', 4),
#  ('votered2020', 4),
#  ('lalate', 4),
#  ('woke', 4),
#  ('bidenisaracist', 4),
#  ('resisters', 4),
#  ('creepyjoe', 4),
#  ('cnnsotu', 4),
#  ('clinton', 4),
#  ('gtcblue', 4),
#  ('americafi', 4),
#  ('trumpsamerica', 4),
#  ('antifajoe', 4),
#  ('countryoverparty', 4),
#  ('keepameri', 4),
#  ('filltheseat', 4),
#  ('entérate', 4),
#  ('billgates', 4),
#  ('hunter', 4),
#  ('com', 4),
#  ('godblesspresidenttrump', 4),
#  ('israel', 4),
#  ('turnitallblue', 4),
#  ('digitalsoldier', 4),
#  ('idiotinchief', 4),
#  ('mailinvoting', 4),
#  ('ournhs', 4),
#  ('covid__19', 4),
#  ('armenia', 4),
#  ('neverbiden', 4),
#  ('thursdaymorning', 4),
#  ('theresistance', 4),
#  ('hope', 4),
#  ('abortion', 4),
#  ('love', 4),
#  ('ronaldreagan', 4),
#  ('trumpcrimefamily_lockthemallup', 4),
#  ('we', 4),
#  ('trumpisamassmurderer', 4),
#  ('trumpvirusdeathtoll210k', 4),
#  ('kda', 4),
#  ('thebad', 4),
#  ('veteransagainsttrump', 4),
#  ('dictatortrump', 4),
#  ('pray', 4),
#  ('adamschiff', 4),
#  ('morons', 4),
#  ('follo', 4),
#  ('checkmate', 4),
#  ('teenvote2020', 4),
#  ('thebestisyettocome', 4),
#  ('lincolnvoter', 4),
#  ('hollyweird', 4),
#  ('democratsareracist', 4),
#  ('texasvotersuppression', 4),
#  ('mikepence', 4),
#  ('thealbum', 4),
#  ('rona', 4),
#  ('bidensf', 4),
#  ('melaniatrumptapes', 4),
#  ('bebestmyass', 4),
#  ('g1', 4),
#  ('hayirlicumalar', 4),
#  ('trumptestspositive', 4),
#  ('octobersurprise', 4),
#  ('fridaymotivation', 4),
#  ('karmafortrump', 4),
#  ('dalitlivesmatter', 4),
#  ('firstlady', 4),
#  ('welovetrump', 4),
#  ('sistemapetroinmobiliario', 4),
#  ('white', 3),
#  ('taxes', 3),
#  ('irs', 3),
#  ('bidenvstrump', 3),
#  ('taxreturns', 3),
#  ('primerdebate', 3),
#  ('redwave2020', 3),
#  ('byedon', 3),
#  ('retweet', 3),
#  ('トランプ大統領', 3),
#  ('kamalaharrisvp', 3),
#  ('maga2020landslide', 3),
#  ('movetrumpout', 3),
#  ('wtf', 3),
#  ('letherdebate', 3),
#  ('trump2020victory', 3),
#  ('quidproquojoe', 3),
#  ('moscowhunter', 3),
#  ('votejoe', 3),
#  ('mrpresident', 3),
#  ('trumpvsbiden2020', 3),
#  ('electionfraud', 3),
#  ('factchecking', 3),
#  ('nothingcanstopwhatiscoming', 3),
#  ('cia', 3),
#  ('harris', 3),
#  ('socialismkills', 3),
#  ('electionday', 3),
#  ('firewraynow', 3),
#  ('8217', 3),
#  ('joewonthedebate', 3),
#  ('uspolitics', 3),
#  ('bi', 3),
#  ('joepayshistaxes', 3),
#  ('trumpdestroysdemocracy', 3),
#  ('romneygardnerladygallspinelessliars', 3),
#  ('thegopisdead', 3),
#  ('presidentbiden', 3),
#  ('pedojoebiden', 3),
#  ('ther', 3),
#  ('maddow', 3),
#  ('quidprojoe', 3),
#  ('magats', 3),
#  ('आत', 3),
#  ('wednesdaymorning', 3),
#  ('november3rd', 3),
#  ('ccpchina', 3),
#  ('digitalsoldiers', 3),
#  ('bodylanguage', 3),
#  ('fakeheadlinebot', 3),
#  ('learntocode', 3),
#  ('makeatwitterbot', 3),
#  ('29sep', 3),
#  ('presidentialdeba', 3),
#  ('world', 3),
#  ('s386', 3),
#  ('blmantifaterroriststhugs', 3),
#  ('voteforamerica', 3),
#  ('cheat', 3),
#  ('trumpisabusive', 3),
#  ('trumpisanabuser', 3),
#  ('r2p', 3),
#  ('england', 3),
#  ('ue', 3),
#  ('people', 3),
#  ('epstein', 3),
#  ('barackobama', 3),
#  ('tinakaggia', 3),
#  ('logo', 3),
#  ('twitter', 3),
#  ('uselection2020', 3),
#  ('usa2020', 3),
#  ('trumpisunfit', 3),
#  ('portland', 3),
#  ('votejoebiden2020', 3),
#  ('antifaisjustanidea', 3),
#  ('s', 3),
#  ('trumpspupils', 3),
#  ('newyork', 3),
#  ('miami', 3),
#  ('c4news', 3),
#  ('uselections', 3),
#  ('unfittobepr', 3),
#  ('nagornokarabakh', 3),
#  ('joe', 3),
#  ('meltdown', 3),
#  ('bfl', 3),
#  ('bidnmobtrmpjob', 3),
#  ('borat', 3),
#  ('notmeus', 3),
#  ('standbackandstandby', 3),
#  ('bidensuc', 3),
#  ('maine', 3),
#  ('nevada', 3),
#  ('pittsburgh', 3),
#  ('bolsonaro', 3),
#  ('voters', 3),
#  ('hate', 3),
#  ('桐生会', 3),
#  ('savecoco', 3),
#  ('proudboysusa', 3),
#  ('deplorables', 3),
#  ('prolifevoicesfortrump', 3),
#  ('veterans', 3),
#  ('trumpobiden', 3),
#  ('thebigapplewillvotefortrump', 3),
#  ('votebluenomatterwho', 3),
#  ('conservative', 3),
#  ('boycottfoxnewssunday', 3),
#  ('frontline', 3),
#  ('pres', 3),
#  ('trumpwon', 3),
#  ('urgente', 3),
#  ('drainthedeepstateswamp', 3),
#  ('inshallah', 3),
#  ('debate20', 3),
#  ('yourvotematters', 3),
#  ('joebidenistheswamp', 3),
#  ('liberal', 3),
#  ('dumbdonald', 3),
#  ('obamagateisreal', 3),
#  ('onlyfans', 3),
#  ('joewon', 3),
#  ('btc', 3),
#  ('votehi', 3),
#  ('tcot', 3),
#  ('chicago', 3),
#  ('conservatives', 3),
#  ('jamalkhashoggi', 3),
#  ('amazon', 3),
#  ('fauci', 3),
#  ('obamagate_treason', 3),
#  ('lindseygrahamislosing', 3),
#  ('democracyoverfascism', 3),
#  ('design', 3),
#  ('karabakh', 3),
#  ('stopazerbaijaniaggression', 3),
#  ('bluetsunami2020', 3),
#  ('traitorssupporttraitortrump', 3),
#  ('alllivesmatter', 3),
#  ('hololive', 3),
#  ('ホロライブ', 3),
#  ('flynn', 3),
#  ('bidenisapedo', 3),
#  ('30sep', 3),
#  ('opportunist', 3),
#  ('votedemsout', 3),
#  ('failedpresident', 3),
#  ('bradparscale', 3),
#  ('katieporter', 3),
#  ('trumphasnoplan', 3),
#  ('trumpresignnow', 3),
#  ('hillaryclinton', 3),
#  ('trumphateso', 3),
#  ('venezuela', 3),
#  ('trumpwonthedebate', 3),
#  ('fox', 3),
#  ('nhpolitics', 3),
#  ('votebluetosaveourdemocracy', 3),
#  ('cspanpoll', 3),
#  ('schoolchoice', 3),
#  ('ditchmitch2020', 3),
#  ('unitednotdivided', 3),
#  ('trumpforprison', 3),
#  ('kag2020landslidevictory', 3),
#  ('fillthatseat', 3),
#  ('wiredup', 3),
#  ('nudist', 3),
#  ('publichealth', 3),
#  ('kylerittenhouseisinnocent', 3),
#  ('criticalracetheory', 3),
#  ('jesus', 3),
#  ('trump2020l', 3),
#  ('pennsylvan', 3),
#  ('1351', 3),
#  ('outofcontrol', 3),
#  ('fiverr', 3),
#  ('amyklobuchar', 3),
#  ('amyklobuhar', 3),
#  ('nomoreofthat', 3),
#  ('getoutthevote', 3),
#  ('courtpacking', 3),
#  ('acbforscotus', 3),
#  ('liars', 3),
#  ('weaponizedprojection', 3),
#  ('mitchmcconnell', 3),
#  ('ad', 3),
#  ('getyabootytot', 3),
#  ('trumpisafraidofovaries', 3),
#  ('faken', 3),
#  ('hypocritecomplicitcow', 3),
#  ('2a', 3),
#  ('lundin', 3),
#  ('25thamendment', 3),
#  ('chavismoresistenciaylealtad', 3),
#  ('chavismore', 3),
#  ('trumpflu', 3),
#  ('joebidenisaracist', 3),
#  ('god', 3),
#  ('trumpde', 3),
#  ('thursdaymotivation', 3),
#  ('jobs', 3),
#  ('azerbaijaniaggression', 3),
#  ('patriots', 3),
#  ('trumpfailedamerica', 3),
#  ('badahbing', 3),
#  ('badahboom', 3),
#  ('voting', 3),
#  ('enoughisenough', 3),
#  ('wtpblue', 3),
#  ('putthatinyourpipe', 3),
#  ('whereishunter', 3),
#  ('joementum', 3),
#  ('keep', 3),
#  ('deepstatethugs', 3),
#  ('ginahaspel', 3),
#  ('trumppressconference', 3),
#  ('tennesseestyle', 3),
#  ('wwg1gwa', 3),
#  ('tedcruzhasnoballs', 3),
#  ('trumpviruscatastrophe', 3),
#  ('climatechange', 3),
#  ('enemyofthepeople', 3),
#  ('masks', 3),
#  ('cleanitup', 3),
#  ('rnc', 3),
#  ('army', 3),
#  ('ralphreed', 3),
#  ('faithandfreedo', 3),
#  ('notsmart', 3),
#  ('patriotsunited4donaldtrump', 3),
#  ('pelosimustgo', 3),
#  ('trumplandslide', 3),
#  ('usps', 3),
#  ('greatawakening', 3),
#  ('hito3millones200mil', 3),
#  ('utpol', 3),
#  ('firesusan', 3),
#  ('marxists', 3),
#  ('misinformation', 3),
#  ('darktolight', 3),
#  ('25thamendmentnow', 3),
#  ('a', 3),
#  ('refusefascism', 3),
#  ('eua', 3),
#  ('lorilightfoot', 3),
#  ('kickoutthewhsquatter', 3),
#  ('patriotsunited', 3),
#  ('democ', 3),
#  ('v', 3),
#  ('trumpvirusdeathtoll211k', 3),
#  ('ampfest20', 3),
#  ('lovesickgirls', 3),
#  ('hickshasthehoax', 3),
#  ('waronchristmas', 3),
#  ('epitwitter', 3),
#  ('lookoverthere', 3),
#  ('elb', 3),
#  ('update', 3),
#  ('simpsons', 3),
#  ('schadenfreude', 3),
#  ('fridaythoughts', 3),
#  ('azt', 3),
#  ('pro', 3),
#  ('protests', 3),
#  ('wearamasksavealife', 3),
#  ('hypocrite', 3),
#  ('كورونا', 3),
#  ('thoughtsandprayers', 3),
#  ('estadosunidos', 3),
#  ('cooperativaencasa', 3),
#  ('stephanierhule', 3),
#  ('flashbackfriday', 3),
#  ('pandemia', 3),
#  ('licra', 3),
#  ('prayforthepresident', 3),
#  ('leftists', 3),
#  ('varneyco', 2),
#  ('jornaldarecord', 2),
#  ('jr24h', 2),
#  ('senate', 2),
#  ('windivisible', 2),
#  ('votethemallout2020', 2),
#  ('biafrafreedom', 2),
#  ('presiden', 2),
#  ('hallelujah', 2),
#  ('supernecessary', 2),
#  ('jojorgensen2020', 2),
#  ('votegold2020', 2),
#  ('debatedrinkinggame', 2),
#  ('backtobluepa', 2),
#  ('justsayin', 2),
#  ('trumpliesmatter', 2),
#  ('malignantnarcissist', 2),
#  ('cripthevote', 2),
#  ('foxfakenews', 2),
#  ('tuesdaydebate', 2),
#  ('orangeidiot', 2),
#  ('factcheckthis', 2),
#  ('marketing', 2),
#  ('socialmedia', 2),
#  ('demonrats', 2),
#  ('tds', 2),
#  ('shutuptrump', 2),
#  ('trumpisanidiot', 2),
#  ('hamsa', 2),
#  ('justice', 2),
#  ('defundthepolice', 2),
#  ('ag', 2),
#  ...]

# %%
full_text_hastags_dict_sorted[:20]
# Out:
# [('debates2020', 2085),
#  ('trump', 675),
#  ('covid19', 511),
#  ('trump2020', 493),
#  ('trumphascovid', 470),
#  ('maga', 428),
#  ('vote', 350),
#  ('presidentialdebate', 307),
#  ('biden', 281),
#  ('debates', 266),
#  ('joebiden', 200),
#  ('bidenwonthedebate', 197),
#  ('bidenharris2020', 183),
#  ('debate2020', 181),
#  ('presidentialdebate2020', 173),
#  ('trumpmeltdown', 163),
#  ('debate', 156),
#  ('donaldtrump', 150),
#  ('chriswallace', 143),
#  ('trumpisaracist', 127)]

# %% [markdown]
# ## Popular Words full_text

# %%
sent = df.full_text.iloc[0]
sent
# Out:
# 'Biden a professional debater??  Hardly!! More like a professional liar! https://t.co/cQuxzexXYt'

# %%
from nltk.tokenize import RegexpTokenizer

# %%
tokenizer = RegexpTokenizer(r"\w+")
tokens = tokenizer.tokenize(sent)
tokens
# Out:
# ['Biden',
#  'a',
#  'professional',
#  'debater',
#  'Hardly',
#  'More',
#  'like',
#  'a',
#  'professional',
#  'liar',
#  'https',
#  't',
#  'co',
#  'cQuxzexXYt']

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered = [w for w in tokens if not w in stop_words]
filtered
# Out:
# ['Biden',
#  'professional',
#  'debater',
#  'Hardly',
#  'More',
#  'like',
#  'professional',
#  'liar',
#  'https',
#  'co',
#  'cQuxzexXYt']

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords


def word_filter(string):
    """
    Input: string, from full_text
    Ouput: list, list of filtered words
    """
    tokenizer = RegexpTokenizer(r"\w+")
    tokens = tokenizer.tokenize(string)
    stop_words_ = set(stopwords.words('english'))
    stop_words_.update({'i'
                        , 'rt'
                        , 'https'
                        , 'co'
                        , 'we'
                        , 'the'
                        , 'he'  
                       }
                      )

    return [w for w in tokens if not w.lower() in stop_words_]

# %%
full_text_filtered = df.full_text.apply(word_filter)

# %%
word_filter(df.full_text.iloc[1])
# Out:
# ['DarDar458', 'PresidentialDebate', 'Debates2020', 'TrumpIsANationalDisgrace']

# %%
full_text_filtered_word_dict = {}
for x in full_text_filtered:
    for y in x:
        if y.lower() in full_text_filtered_word_dict:
            full_text_filtered_word_dict[y.lower()] += 1
        else:
            full_text_filtered_word_dict[y.lower()] = 1

# %%
full_text_filtered_word_dict_sorted = sorted(full_text_filtered_word_dict.items()
                                             , key=lambda kv: kv[1]
                                             , reverse=True
                                            )
full_text_filtered_word_dict_sorted[:30]
# Out:
# [('trump', 55967),
#  ('realdonaldtrump', 30151),
#  ('biden', 28402),
#  ('president', 14308),
#  ('debate', 12434),
#  ('joebiden', 11856),
#  ('joe', 11374),
#  ('covid', 10591),
#  ('white', 9240),
#  ('tested', 6882),
#  ('flotus', 6508),
#  ('donald', 6484),
#  ('positive', 6329),
#  ('people', 6157),
#  ('19', 5864),
#  ('tonight', 5806),
#  ('like', 5468),
#  ('amp', 5151),
#  ('vote', 4947),
#  ('one', 4786),
#  ('said', 4545),
#  ('wallace', 4391),
#  ('last', 4155),
#  ('would', 4077),
#  ('recovery', 4047),
#  ('know', 3703),
#  ('first', 3667),
#  ('get', 3614),
#  ('chris', 3542),
#  ('immediately', 3534)]

# %% [markdown]
# ## Count of tweets by datetime hours

# %%
df_dt = df
df_dt.index = df['datetime']
df_dt_hour = df_dt.resample('H').count()
df_dt_hour
# Out:
#                            id_str  full_text  entities  source  user  \
# datetime
# 2020-09-29 23:00:00+00:00       2          2         2       2     2
# 2020-09-30 00:00:00+00:00    1799       1799      1799    1799  1799
# 2020-09-30 01:00:00+00:00    2255       2255      2255    2255  2255
# 2020-09-30 02:00:00+00:00    3068       3068      3068    3068  3068
# 2020-09-30 03:00:00+00:00    2643       2643      2643    2643  2643
# ...                           ...        ...       ...     ...   ...
# 2020-10-02 19:00:00+00:00    1835       1835      1835    1835  1835
# 2020-10-02 20:00:00+00:00    1830       1830      1830    1829  1830
# 2020-10-02 21:00:00+00:00    1810       1810      1810    1810  1810
# 2020-10-02 22:00:00+00:00    2275       2275      2275    2275  2275
# 2020-10-02 23:00:00+00:00    2141       2141      2141    2141  2141
#
#                            is_quote_status  retweet_count  favorite_count  \
# datetime
# 2020-09-29 23:00:00+00:00                2              2               2
# 2020-09-30 00:00:00+00:00             1799           1799            1799
# 2020-09-30 01:00:00+00:00             2255           2255            2255
# 2020-09-30 02:00:00+00:00             3068           3068            3068
# 2020-09-30 03:00:00+00:00             2643           2643            2643
# ...                                    ...            ...             ...
# 2020-10-02 19:00:00+00:00             1835           1835            1835
# 2020-10-02 20:00:00+00:00             1830           1830            1830
# 2020-10-02 21:00:00+00:00             1810           1810            1810
# 2020-10-02 22:00:00+00:00             2275           2275            2275
# 2020-10-02 23:00:00+00:00             2141           2141            2141
#
#                            possibly_sensitive  lang  ...  statuses_count  \
# datetime                                             ...
# 2020-09-29 23:00:00+00:00                   1     2  ...               2
# 2020-09-30 00:00:00+00:00                 416  1799  ...            1799
# 2020-09-30 01:00:00+00:00                 509  2255  ...            2255
# 2020-09-30 02:00:00+00:00                 807  3068  ...            3068
# 2020-09-30 03:00:00+00:00                 660  2643  ...            2643
# ...                                       ...   ...  ...             ...
# 2020-10-02 19:00:00+00:00                 394  1835  ...            1835
# 2020-10-02 20:00:00+00:00                 407  1830  ...            1830
# 2020-10-02 21:00:00+00:00                 409  1810  ...            1810
# 2020-10-02 22:00:00+00:00                 785  2275  ...            2275
# 2020-10-02 23:00:00+00:00                 567  2141  ...            2141
#
#                            following  following_request  notifications  \
# datetime
# 2020-09-29 23:00:00+00:00          2                  2              2
# 2020-09-30 00:00:00+00:00       1799               1799           1799
# 2020-09-30 01:00:00+00:00       2255               2255           2255
# 2020-09-30 02:00:00+00:00       3068               3068           3068
# 2020-09-30 03:00:00+00:00       2643               2643           2643
# ...                              ...                ...            ...
# 2020-10-02 19:00:00+00:00       1835               1835           1835
# 2020-10-02 20:00:00+00:00       1830               1830           1830
# 2020-10-02 21:00:00+00:00       1810               1810           1810
# 2020-10-02 22:00:00+00:00       2275               2275           2275
# 2020-10-02 23:00:00+00:00       2141               2141           2141
#
#                            user_descriptions  sentiment_scores  \
# datetime
# 2020-09-29 23:00:00+00:00                  2                 2
# 2020-09-30 00:00:00+00:00               1799              1799
# 2020-09-30 01:00:00+00:00               2255              2255
# 2020-09-30 02:00:00+00:00               3068              3068
# 2020-09-30 03:00:00+00:00               2643              2643
# ...                                      ...               ...
# 2020-10-02 19:00:00+00:00               1835              1835
# 2020-10-02 20:00:00+00:00               1830              1830
# 2020-10-02 21:00:00+00:00               1810              1810
# 2020-10-02 22:00:00+00:00               2275              2275
# 2020-10-02 23:00:00+00:00               2141              2141
#
#                            compound_score  sentiment  Biden_mentions  \
# datetime
# 2020-09-29 23:00:00+00:00               2          2               2
# 2020-09-30 00:00:00+00:00            1799       1799            1799
# 2020-09-30 01:00:00+00:00            2255       2255            2255
# 2020-09-30 02:00:00+00:00            3068       3068            3068
# 2020-09-30 03:00:00+00:00            2643       2643            2643
# ...                                   ...        ...             ...
# 2020-10-02 19:00:00+00:00            1835       1835            1835
# 2020-10-02 20:00:00+00:00            1830       1830            1830
# 2020-10-02 21:00:00+00:00            1810       1810            1810
# 2020-10-02 22:00:00+00:00            2275       2275            2275
# 2020-10-02 23:00:00+00:00            2141       2141            2141
#
#                            Trump_mentions
# datetime
# 2020-09-29 23:00:00+00:00               2
# 2020-09-30 00:00:00+00:00            1799
# 2020-09-30 01:00:00+00:00            2255
# 2020-09-30 02:00:00+00:00            3068
# 2020-09-30 03:00:00+00:00            2643
# ...                                   ...
# 2020-10-02 19:00:00+00:00            1835
# 2020-10-02 20:00:00+00:00            1830
# 2020-10-02 21:00:00+00:00            1810
# 2020-10-02 22:00:00+00:00            2275
# 2020-10-02 23:00:00+00:00            2141
#
# [73 rows x 28 columns]

# %%
# make a plot function
def plot_func(x, y, xlabel, ylabel, title):
    """
    Makes a plot given x and y values
    
    Inputs: x, y series from dataframe
            xlable, ylabel, string of axis labels
            title, string 
            
    Ouputs: None, generates scatter plot
    """
    plt.figure(figsize = (9,7))
    plt.scatter(x, y)
    plt.title(title, fontsize=25)
    plt.xlabel(xlabel, fontsize=20)
    plt.xticks(rotation = 45)
    plt.ylabel(ylabel, fontsize=20);

# %%
plot_func(df_dt_hour.index
          , df_dt_hour.id_str
          , 'Time (hours)'
          , 'Count'
          , "Tweet Count by Hour"
          , 
         )

# %%
df_dt_min = df_dt.resample('1min').count()
df_dt_min
# Out:
#                            id_str  full_text  entities  source  user  \
# datetime
# 2020-09-29 23:59:00+00:00       2          2         2       2     2
# 2020-09-30 00:00:00+00:00      32         32        32      32    32
# 2020-09-30 00:01:00+00:00      31         31        31      31    31
# 2020-09-30 00:02:00+00:00      31         31        31      31    31
# 2020-09-30 00:03:00+00:00      31         31        31      31    31
# ...                           ...        ...       ...     ...   ...
# 2020-10-02 23:55:00+00:00      36         36        36      36    36
# 2020-10-02 23:56:00+00:00      36         36        36      36    36
# 2020-10-02 23:57:00+00:00      35         35        35      35    35
# 2020-10-02 23:58:00+00:00      35         35        35      35    35
# 2020-10-02 23:59:00+00:00      29         29        29      29    29
#
#                            is_quote_status  retweet_count  favorite_count  \
# datetime
# 2020-09-29 23:59:00+00:00                2              2               2
# 2020-09-30 00:00:00+00:00               32             32              32
# 2020-09-30 00:01:00+00:00               31             31              31
# 2020-09-30 00:02:00+00:00               31             31              31
# 2020-09-30 00:03:00+00:00               31             31              31
# ...                                    ...            ...             ...
# 2020-10-02 23:55:00+00:00               36             36              36
# 2020-10-02 23:56:00+00:00               36             36              36
# 2020-10-02 23:57:00+00:00               35             35              35
# 2020-10-02 23:58:00+00:00               35             35              35
# 2020-10-02 23:59:00+00:00               29             29              29
#
#                            possibly_sensitive  lang  ...  statuses_count  \
# datetime                                             ...
# 2020-09-29 23:59:00+00:00                   1     2  ...               2
# 2020-09-30 00:00:00+00:00                   6    32  ...              32
# 2020-09-30 00:01:00+00:00                   7    31  ...              31
# 2020-09-30 00:02:00+00:00                   5    31  ...              31
# 2020-09-30 00:03:00+00:00                   9    31  ...              31
# ...                                       ...   ...  ...             ...
# 2020-10-02 23:55:00+00:00                   8    36  ...              36
# 2020-10-02 23:56:00+00:00                   7    36  ...              36
# 2020-10-02 23:57:00+00:00                   8    35  ...              35
# 2020-10-02 23:58:00+00:00                   8    35  ...              35
# 2020-10-02 23:59:00+00:00                   9    29  ...              29
#
#                            following  following_request  notifications  \
# datetime
# 2020-09-29 23:59:00+00:00          2                  2              2
# 2020-09-30 00:00:00+00:00         32                 32             32
# 2020-09-30 00:01:00+00:00         31                 31             31
# 2020-09-30 00:02:00+00:00         31                 31             31
# 2020-09-30 00:03:00+00:00         31                 31             31
# ...                              ...                ...            ...
# 2020-10-02 23:55:00+00:00         36                 36             36
# 2020-10-02 23:56:00+00:00         36                 36             36
# 2020-10-02 23:57:00+00:00         35                 35             35
# 2020-10-02 23:58:00+00:00         35                 35             35
# 2020-10-02 23:59:00+00:00         29                 29             29
#
#                            user_descriptions  sentiment_scores  \
# datetime
# 2020-09-29 23:59:00+00:00                  2                 2
# 2020-09-30 00:00:00+00:00                 32                32
# 2020-09-30 00:01:00+00:00                 31                31
# 2020-09-30 00:02:00+00:00                 31                31
# 2020-09-30 00:03:00+00:00                 31                31
# ...                                      ...               ...
# 2020-10-02 23:55:00+00:00                 36                36
# 2020-10-02 23:56:00+00:00                 36                36
# 2020-10-02 23:57:00+00:00                 35                35
# 2020-10-02 23:58:00+00:00                 35                35
# 2020-10-02 23:59:00+00:00                 29                29
#
#                            compound_score  sentiment  Biden_mentions  \
# datetime
# 2020-09-29 23:59:00+00:00               2          2               2
# 2020-09-30 00:00:00+00:00              32         32              32
# 2020-09-30 00:01:00+00:00              31         31              31
# 2020-09-30 00:02:00+00:00              31         31              31
# 2020-09-30 00:03:00+00:00              31         31              31
# ...                                   ...        ...             ...
# 2020-10-02 23:55:00+00:00              36         36              36
# 2020-10-02 23:56:00+00:00              36         36              36
# 2020-10-02 23:57:00+00:00              35         35              35
# 2020-10-02 23:58:00+00:00              35         35              35
# 2020-10-02 23:59:00+00:00              29         29              29
#
#                            Trump_mentions
# datetime
# 2020-09-29 23:59:00+00:00               2
# 2020-09-30 00:00:00+00:00              32
# 2020-09-30 00:01:00+00:00              31
# 2020-09-30 00:02:00+00:00              31
# 2020-09-30 00:03:00+00:00              31
# ...                                   ...
# 2020-10-02 23:55:00+00:00              36
# 2020-10-02 23:56:00+00:00              36
# 2020-10-02 23:57:00+00:00              35
# 2020-10-02 23:58:00+00:00              35
# 2020-10-02 23:59:00+00:00              29
#
# [4321 rows x 28 columns]

# %%
plot_func(df_dt_min.index
          , df_dt_min.id_str
          , 'Time (Min)'
          , 'Count'
          , 'Tweet Count by Minute'
         )

# %%
# 9/30/2020 Trump refuses to condemn white supremesist
# 10/2/2020 Prez and 1st lady tests postiive for COVID-19
